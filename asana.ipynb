# %%
from flask import Flask, request, jsonify
from flask_cors import CORS, cross_origin
import openai
import requests
import json
from dotenv import load_dotenv
import os
from functools import lru_cache
import asana

# %%
# Load environment variables from .env file
load_dotenv()

# Set up API key
ASANA_API_KEY = os.getenv('ASANA_API_KEY')
client = asana.Client.access_token(ASANA_API_KEY)

# %%
# Load environment variables from .env file
load_dotenv()

# Set up API key
ASANA_API_KEY = os.getenv('ASANA_API_KEY')
project_gid = '1203880491753826' # master script
url = f"https://app.asana.com/api/1.0/projects/{project_gid}/custom_field_settings"

headers = {
    "Authorization": f"Bearer {ASANA_API_KEY}",
}

response = requests.get(url, headers=headers)
result = response.json()

# %%
fields_by_gid = {}
for field in result['data'][0]['custom_field']:
    fields_by_gid[field['name']] = field['gid']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/kuoyihsin/My Drive/2工作/AICS/InDev/GPT-testCase-Generator/asana.ipynb Cell 4 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/kuoyihsin/My%20Drive/2%E5%B7%A5%E4%BD%9C/AICS/InDev/GPT-testCase-Generator/asana.ipynb#X44sZmlsZQ%3D%3D?line=0'>1</a> fields_by_gid = {}
#       <a href='vscode-notebook-cell:/Users/kuoyihsin/My%20Drive/2%E5%B7%A5%E4%BD%9C/AICS/InDev/GPT-testCase-Generator/asana.ipynb#X44sZmlsZQ%3D%3D?line=1'>2</a> for field in result['data'][0]['custom_field']:
# ----> <a href='vscode-notebook-cell:/Users/kuoyihsin/My%20Drive/2%E5%B7%A5%E4%BD%9C/AICS/InDev/GPT-testCase-Generator/asana.ipynb#X44sZmlsZQ%3D%3D?line=2'>3</a>     fields_by_gid[field['name']] = field['gid']
#
# TypeError: string indices must be integers

# %%
fields = {}
for item in result['data']:
    if item['custom_field']['type'] in ['enum','multi_enum']:
        enum_options = item['custom_field']['enum_options']
        option_gid = {opt['name']: opt['gid'] for opt in enum_options}
        fields[item['custom_field']['name']] = {'enum_options': option_gid, 'type': item['custom_field']['type']}
    else:
        fields[item['custom_field']['name']] = {'type': item['custom_field']['type']}

# %%
fields
# Out:
# {'Effort': {'type': 'number'},
#  'CaseSuite': {'enum_options': {'即檢及列印': '1204387003439606',
#    '身分設定': '1203934098502916',
#    'SOAP': '1203934098502998',
#    '下診斷ICD': '1203934098503008',
#    '藥囑': '1203934098503062',
#    '醫囑': '1203934098502921',
#    '歷史病歷': '1203934098502962',
#    '稽核Rule': '1203934098503027',
#    '報告查詢': '1203934098502976',
#    '套餐(醫療)': '1203934098502991',
#    '就診明細': '1204466983046954',
#    '完成看診': '1203934098502834',
#    '身體數據': '1203934098502941',
#    '健保雲端': '1203934098502936',
#    '暫存及存回舊系統': '1204278087004936',
#    '清空看診資料(病歷維護)': '1204278011832310',
#    '健保卡及醫事卡': '1204124924017144',
#    '病患清單': '1203934098502908',
#    'Login': '1203934098502854',
#    'CPOE': '1204150600824431',
#    '院內公告': '1203934098502865',
#    '過敏及不良反應': '1203934098502956',
#    '列印': '1203934098502933',
#    '問卷': '1203934098502945',
#    '轉診': '1203934098502953',
#    'LifeCycle': '1203934098502860',
#    '環境設備': '1203934098502835',
#    '手術': '1203934098502965',
#    '電子表單': '1203934098502988',
#    '系統交互': '1203934098503005',
#    '電子病歷': '1203934098503248',
#    '疫苗': '1203934098503013',
#    '偕同編輯': '1203934098503070',
#    '掛號': '1203934098503072',
#    'DataSyc': '1203934098503076',
#    '再次完成看診': '1203934098503081',
#    '癌症相關': '1203934098503238',
#    '災難復原測試': '1203943007360272',
#    '架構及技術': '1203964893026037',
#    '個案管理': '1204161832030784',
#    '批價帳務': '1204172009992256',
#    '保險申報': '1204172009992257',
#    '其他': '1203934098503078',
#    'UI': '1204437681145655'},
#   'type': 'multi_enum'},
#  'Manual Test Coverage': {'enum_options': {'Smoke': '1203934098501464',
#    'Quick': '1203934098501465',
#    'Partial': '1203934098501466',
#    'Full': '1203934098501467',
#    'Backlog': '1203934098501469',
#    'DefectVerify': '1204124924017134',
#    'FectureVerify': '1204161832030785',
#    'E2E': '1204222443390009',
#    'Use Case': '1204222443390010',
#    'Offline': '1203943007360270'},
#   'type': 'multi_enum'},
#  'Manual Test Priority': {'enum_options': {'High': '1204395740629736',
#    'Medium': '1204395740629737',
#    'Low': '1204395740629738'},
#   'type': 'enum'},
#  'Pre-Condition': {'type': 'text'},
#  'Test Step': {'type': 'text'},
#  'Expected Result': {'type': 'text'},
#  'Post-Condition': {'type': 'text'},
#  'xRelease': {'enum_options': {'v.next Hotfix': '1204191076977825',
#    'v.next Feature': '1204191215556915',
#    'XRT0011W': '1204370943928676',
#    'XRT0010H': '1204370943928675',
#    'XRT0009W': '1204256012972448',
#    'XRT0008H': '1204213162513273',
#    'XRT0007W': '1204151393723066',
#    'XRT0006H': '1204151393723067',
#    'XRT0005H': '1204190912755613',
#    'XRT0004W': '1204190396223455'},
#   'type': 'multi_enum'},
#  'Manual Test Date': {'type': 'date'},
#  'Manual Test Environment': {'enum_options': {'INTT': '1203926363806261',
#    'STAGE': '1203926363806262',
#    'PROD': '1203926363806263',
#    'DEV': '1204305354230536'},
#   'type': 'enum'},
#  'Manual Test Result': {'enum_options': {'Testing': '1204278011832321',
#    'Passed': '1203926363806256',
#    'Failed': '1203926363806257',
#    'Triage': '1203926363806258',
#    'Pass with Note': '1204447833841095'},
#   'type': 'enum'},
#  'Manual Test Comment': {'type': 'text'},
#  'Role': {'enum_options': {'醫師': '1203880512051790',
#    '跟診': '1203880512051791',
#    '二線科人員': '1203880512051798',
#    '藥師': '1203880512051792',
#    '營養師': '1203880512051793',
#    'ALL': '1203954415389020'},
#   'type': 'multi_enum'},
#  'Case Source': {'enum_options': {'PRD': '1203964893025996',
#    'Defect': '1203964893025997',
#    'Testing': '1203964893025998',
#    'ETC': '1203964893025999',
#    'CR': '1204203317450647',
#    'E2E': '1204222443390006',
#    'Use Case': '1204222443390007',
#    'Acceptance Criteria': '1204222443390008'},
#   'type': 'enum'},
#  'PRD': {'type': 'text'},
#  'MainTicket': {'type': 'text'},
#  'Non-xHIS': {'enum_options': {'CC Module': '1203934098502869',
#    'CC Web': '1203934098502990',
#    'AICS SaaS': '1203946901342662',
#    'Third Party': '1203934098502870',
#    'Azure SaaS': '1203943007360274'},
#   'type': 'multi_enum'},
#  'Automation Assignee': {'type': 'people'},
#  'Automation Status': {'enum_options': {'Automated': '1204036362646081',
#    '進行中': '1204036362646082',
#    'Partially Automated': '1204124699309640',
#    'In Progress': '1204115697181473',
#    '待討論': '1204036364493279',
#    'To Automate': '1204115697181474',
#    'Manual': '1204234906053321',
#    'TBD': '1204234733879588'},
#   'type': 'enum'},
#  'Automation ID': {'type': 'text'},
#  'Automation Comments': {'type': 'text'},
#  'Generated By': {'enum_options': {'Human': '1204352561007624',
#    'gpt-3.5-turbo': '1204352561007625'},
#   'type': 'enum'},
#  'Prompt Token': {'type': 'number'},
#  'Completion Token': {'type': 'number'},
#  'Total Token': {'type': 'number'},
#  'Incur Time Cost': {'type': 'text'}}

# %%
fields
# Out:
# {'CaseSuite': {'enum_options': {'即檢及列印': '1204387003439606',
#    '身分設定': '1203934098502916',
#    'SOAP': '1203934098502998',
#    '下診斷ICD': '1203934098503008',
#    '藥囑': '1203934098503062',
#    '醫囑': '1203934098502921',
#    '歷史病歷': '1203934098502962',
#    '稽核Rule': '1203934098503027',
#    '報告查詢': '1203934098502976',
#    '套餐(醫療)': '1203934098502991',
#    '就診明細': '1204466983046954',
#    '完成看診': '1203934098502834',
#    '身體數據': '1203934098502941',
#    '健保雲端': '1203934098502936',
#    '暫存及存回舊系統': '1204278087004936',
#    '清空看診資料(病歷維護)': '1204278011832310',
#    '健保卡及醫事卡': '1204124924017144',
#    '病患清單': '1203934098502908',
#    'Login': '1203934098502854',
#    'CPOE': '1204150600824431',
#    '院內公告': '1203934098502865',
#    '過敏及不良反應': '1203934098502956',
#    '列印': '1203934098502933',
#    '問卷': '1203934098502945',
#    '轉診': '1203934098502953',
#    'LifeCycle': '1203934098502860',
#    '環境設備': '1203934098502835',
#    '手術': '1203934098502965',
#    '電子表單': '1203934098502988',
#    '系統交互': '1203934098503005',
#    '電子病歷': '1203934098503248',
#    '疫苗': '1203934098503013',
#    '偕同編輯': '1203934098503070',
#    '掛號': '1203934098503072',
#    'DataSyc': '1203934098503076',
#    '再次完成看診': '1203934098503081',
#    '癌症相關': '1203934098503238',
#    '災難復原測試': '1203943007360272',
#    '架構及技術': '1203964893026037',
#    '個案管理': '1204161832030784',
#    '批價帳務': '1204172009992256',
#    '保險申報': '1204172009992257',
#    '其他': '1203934098503078',
#    'UI': '1204437681145655'},
#   'type': 'multi_enum'},
#  'Manual Test Coverage': {'enum_options': {'Smoke': '1203934098501464',
#    'Quick': '1203934098501465',
#    'Partial': '1203934098501466',
#    'Full': '1203934098501467',
#    'Backlog': '1203934098501469',
#    'DefectVerify': '1204124924017134',
#    'FectureVerify': '1204161832030785',
#    'E2E': '1204222443390009',
#    'Use Case': '1204222443390010',
#    'Offline': '1203943007360270'},
#   'type': 'multi_enum'},
#  'Manual Test Priority': {'enum_options': {'High': '1204395740629736',
#    'Medium': '1204395740629737',
#    'Low': '1204395740629738'},
#   'type': 'enum'},
#  'xRelease': {'enum_options': {'v.next Hotfix': '1204191076977825',
#    'v.next Feature': '1204191215556915',
#    'XRT0011W': '1204370943928676',
#    'XRT0010H': '1204370943928675',
#    'XRT0009W': '1204256012972448',
#    'XRT0008H': '1204213162513273',
#    'XRT0007W': '1204151393723066',
#    'XRT0006H': '1204151393723067',
#    'XRT0005H': '1204190912755613',
#    'XRT0004W': '1204190396223455'},
#   'type': 'multi_enum'},
#  'Manual Test Environment': {'enum_options': {'INTT': '1203926363806261',
#    'STAGE': '1203926363806262',
#    'PROD': '1203926363806263',
#    'DEV': '1204305354230536'},
#   'type': 'enum'},
#  'Manual Test Result': {'enum_options': {'Testing': '1204278011832321',
#    'Passed': '1203926363806256',
#    'Failed': '1203926363806257',
#    'Triage': '1203926363806258',
#    'Pass with Note': '1204447833841095'},
#   'type': 'enum'},
#  'Role': {'enum_options': {'醫師': '1203880512051790',
#    '跟診': '1203880512051791',
#    '二線科人員': '1203880512051798',
#    '藥師': '1203880512051792',
#    '營養師': '1203880512051793',
#    'ALL': '1203954415389020'},
#   'type': 'multi_enum'},
#  'Case Source': {'enum_options': {'PRD': '1203964893025996',
#    'Defect': '1203964893025997',
#    'Testing': '1203964893025998',
#    'ETC': '1203964893025999',
#    'CR': '1204203317450647',
#    'E2E': '1204222443390006',
#    'Use Case': '1204222443390007',
#    'Acceptance Criteria': '1204222443390008'},
#   'type': 'enum'},
#  'Non-xHIS': {'enum_options': {'CC Module': '1203934098502869',
#    'CC Web': '1203934098502990',
#    'AICS SaaS': '1203946901342662',
#    'Third Party': '1203934098502870',
#    'Azure SaaS': '1203943007360274'},
#   'type': 'multi_enum'},
#  'Automation Status': {'enum_options': {'Automated': '1204036362646081',
#    '進行中': '1204036362646082',
#    'Partially Automated': '1204124699309640',
#    'In Progress': '1204115697181473',
#    '待討論': '1204036364493279',
#    'To Automate': '1204115697181474',
#    'Manual': '1204234906053321',
#    'TBD': '1204234733879588'},
#   'type': 'enum'},
#  'Generated By': {'enum_options': {'Human': '1204352561007624',
#    'gpt-3.5-turbo': '1204352561007625'},
#   'type': 'enum'}}

# %%
formData = {'name': '個人memo功能異常', 'caseSuite': ['其他', '身分設定'], 'manualTestCoverage': 'Partial', 'preCondition': '已經進入病患清單並使用過個人memo功能', 'testStep': '1. 回到病患清單\n2. 再次進入該病人的個人memo\n3. 點選存回舊系統/完成看診\n4. 再次進入該病人的個人memo\n5. 點選全院memo\n6. 再點回個人memo', 'expectedResult': '1. 回到病患清單\n2. 個人memo還在\n3. 存回舊系統/完成看診成功且個人memo仍在\n4. 個人memo文字未消失，功能正常\n5. 可以進入全院memo\n6. 再次進入個人memo，文字未消失，功能正常', 'manualTestEnvironment': 'STAGE', 'caseSource': 'Defect', 'mainTicket': 'https://app.asana.com/0/1201610634708103/1203751583595248/f', 'generatedBy': 'gpt-3.5-turbo'}

# %%
custom_field_data = {
    "CaseSuite": formData['caseSuite'],
    "Manual Test Coverage": formData["manualTestCoverage"],
    "Case Source": formData['caseSource'],
    "Generated By": formData['generatedBy'],
    "MainTicket": formData['mainTicket'],
    "Manual Test Environment": formData['manualTestEnvironment'],
    "Pre-Condition": formData['preCondition'],
    "Test Step": formData['testStep'],
    "Expected Result": formData['expectedResult'],

}

# %%
custom_field_data  = fields

# %%
type(custom_field_data.get("Manual Test Coverage"))
# Out:
# str

# %%
type(field_options['enum_options'].get(custom_field_data.get("Manual Test Coverage")))
# Out:
# NoneType

# %%
custom_fields
# Out:
# {'CaseSuite': ['1203934098503078', '1203934098502916'],
#  'Manual Test Coverage': ['1203934098501466'],
#  'Manual Test Environment': '1203926363806262',
#  'Case Source': '1203964893025997',
#  'Generated By': '1204352561007625'}

# %%
fields
# Out:
# {'Effort': {'type': 'number'},
#  'CaseSuite': {'enum_options': {'即檢及列印': '1204387003439606',
#    '身分設定': '1203934098502916',
#    'SOAP': '1203934098502998',
#    '下診斷ICD': '1203934098503008',
#    '藥囑': '1203934098503062',
#    '醫囑': '1203934098502921',
#    '歷史病歷': '1203934098502962',
#    '稽核Rule': '1203934098503027',
#    '報告查詢': '1203934098502976',
#    '套餐(醫療)': '1203934098502991',
#    '就診明細': '1204466983046954',
#    '完成看診': '1203934098502834',
#    '身體數據': '1203934098502941',
#    '健保雲端': '1203934098502936',
#    '暫存及存回舊系統': '1204278087004936',
#    '清空看診資料(病歷維護)': '1204278011832310',
#    '健保卡及醫事卡': '1204124924017144',
#    '病患清單': '1203934098502908',
#    'Login': '1203934098502854',
#    'CPOE': '1204150600824431',
#    '院內公告': '1203934098502865',
#    '過敏及不良反應': '1203934098502956',
#    '列印': '1203934098502933',
#    '問卷': '1203934098502945',
#    '轉診': '1203934098502953',
#    'LifeCycle': '1203934098502860',
#    '環境設備': '1203934098502835',
#    '手術': '1203934098502965',
#    '電子表單': '1203934098502988',
#    '系統交互': '1203934098503005',
#    '電子病歷': '1203934098503248',
#    '疫苗': '1203934098503013',
#    '偕同編輯': '1203934098503070',
#    '掛號': '1203934098503072',
#    'DataSyc': '1203934098503076',
#    '再次完成看診': '1203934098503081',
#    '癌症相關': '1203934098503238',
#    '災難復原測試': '1203943007360272',
#    '架構及技術': '1203964893026037',
#    '個案管理': '1204161832030784',
#    '批價帳務': '1204172009992256',
#    '保險申報': '1204172009992257',
#    '其他': '1203934098503078',
#    'UI': '1204437681145655'},
#   'type': 'multi_enum'},
#  'Manual Test Coverage': {'enum_options': {'Smoke': '1203934098501464',
#    'Quick': '1203934098501465',
#    'Partial': '1203934098501466',
#    'Full': '1203934098501467',
#    'Backlog': '1203934098501469',
#    'DefectVerify': '1204124924017134',
#    'FectureVerify': '1204161832030785',
#    'E2E': '1204222443390009',
#    'Use Case': '1204222443390010',
#    'Offline': '1203943007360270'},
#   'type': 'multi_enum'},
#  'Manual Test Priority': {'enum_options': {'High': '1204395740629736',
#    'Medium': '1204395740629737',
#    'Low': '1204395740629738'},
#   'type': 'enum'},
#  'Pre-Condition': {'type': 'text'},
#  'Test Step': {'type': 'text'},
#  'Expected Result': {'type': 'text'},
#  'Post-Condition': {'type': 'text'},
#  'xRelease': {'enum_options': {'v.next Hotfix': '1204191076977825',
#    'v.next Feature': '1204191215556915',
#    'XRT0011W': '1204370943928676',
#    'XRT0010H': '1204370943928675',
#    'XRT0009W': '1204256012972448',
#    'XRT0008H': '1204213162513273',
#    'XRT0007W': '1204151393723066',
#    'XRT0006H': '1204151393723067',
#    'XRT0005H': '1204190912755613',
#    'XRT0004W': '1204190396223455'},
#   'type': 'multi_enum'},
#  'Manual Test Date': {'type': 'date'},
#  'Manual Test Environment': {'enum_options': {'INTT': '1203926363806261',
#    'STAGE': '1203926363806262',
#    'PROD': '1203926363806263',
#    'DEV': '1204305354230536'},
#   'type': 'enum'},
#  'Manual Test Result': {'enum_options': {'Testing': '1204278011832321',
#    'Passed': '1203926363806256',
#    'Failed': '1203926363806257',
#    'Triage': '1203926363806258',
#    'Pass with Note': '1204447833841095'},
#   'type': 'enum'},
#  'Manual Test Comment': {'type': 'text'},
#  'Role': {'enum_options': {'醫師': '1203880512051790',
#    '跟診': '1203880512051791',
#    '二線科人員': '1203880512051798',
#    '藥師': '1203880512051792',
#    '營養師': '1203880512051793',
#    'ALL': '1203954415389020'},
#   'type': 'multi_enum'},
#  'Case Source': {'enum_options': {'PRD': '1203964893025996',
#    'Defect': '1203964893025997',
#    'Testing': '1203964893025998',
#    'ETC': '1203964893025999',
#    'CR': '1204203317450647',
#    'E2E': '1204222443390006',
#    'Use Case': '1204222443390007',
#    'Acceptance Criteria': '1204222443390008'},
#   'type': 'enum'},
#  'PRD': {'type': 'text'},
#  'MainTicket': {'type': 'text'},
#  'Non-xHIS': {'enum_options': {'CC Module': '1203934098502869',
#    'CC Web': '1203934098502990',
#    'AICS SaaS': '1203946901342662',
#    'Third Party': '1203934098502870',
#    'Azure SaaS': '1203943007360274'},
#   'type': 'multi_enum'},
#  'Automation Assignee': {'type': 'people'},
#  'Automation Status': {'enum_options': {'Automated': '1204036362646081',
#    '進行中': '1204036362646082',
#    'Partially Automated': '1204124699309640',
#    'In Progress': '1204115697181473',
#    '待討論': '1204036364493279',
#    'To Automate': '1204115697181474',
#    'Manual': '1204234906053321',
#    'TBD': '1204234733879588'},
#   'type': 'enum'},
#  'Automation ID': {'type': 'text'},
#  'Automation Comments': {'type': 'text'},
#  'Generated By': {'enum_options': {'Human': '1204352561007624',
#    'gpt-3.5-turbo': '1204352561007625'},
#   'type': 'enum'},
#  'Prompt Token': {'type': 'number'},
#  'Completion Token': {'type': 'number'},
#  'Total Token': {'type': 'number'},
#  'Incur Time Cost': {'type': 'text'}}

# %%
custom_fields
# Out:
# {'CaseSuite': ['1203934098503078', '1203934098502916'],
#  'Manual Test Coverage': ['1203934098501466'],
#  'Pre-Condition': '已經進入病患清單並使用過個人memo功能',
#  'Test Step': '1. 回到病患清單\n2. 再次進入該病人的個人memo\n3. 點選存回舊系統/完成看診\n4. 再次進入該病人的個人memo\n5. 點選全院memo\n6. 再點回個人memo',
#  'Expected Result': '1. 回到病患清單\n2. 個人memo還在\n3. 存回舊系統/完成看診成功且個人memo仍在\n4. 個人memo文字未消失，功能正常\n5. 可以進入全院memo\n6. 再次進入個人memo，文字未消失，功能正常',
#  'Manual Test Environment': '1203926363806262',
#  'Case Source': '1203964893025997',
#  'MainTicket': 'https://app.asana.com/0/1201610634708103/1203751583595248/f',
#  'Generated By': '1204352561007625'}

# %%
project_gid = '1203880491753826'  # master script

result = client.tasks.create_task({
    "projects": [project_gid],
    "name": formData['name'],
    "custom_fields": custom_fields_final 
})
# Out:
# /Users/kuoyihsin/opt/anaconda3/lib/python3.9/site-packages/asana/client.py:156: UserWarning: This request is affected by the "new_user_task_lists" deprecation. Please visit this url for more info: https://forum.asana.com/t/update-on-our-planned-api-changes-to-user-task-lists-a-k-a-my-tasks/103828
# Adding "new_user_task_lists" to your "Asana-Enable" or "Asana-Disable" header will opt in/out to this deprecation and suppress this warning.
#   warnings.warn(message)
# /Users/kuoyihsin/opt/anaconda3/lib/python3.9/site-packages/asana/client.py:156: UserWarning: This request is affected by the "new_goal_memberships" deprecation. Please visit this url for more info: https://forum.asana.com/t/launched-team-sharing-for-goals/378601
# Adding "new_goal_memberships" to your "Asana-Enable" or "Asana-Disable" header will opt in/out to this deprecation and suppress this warning.
#   warnings.warn(message)

# %%
custom_fields
# Out:
# {'CaseSuite': ['1203934098503078', '1203934098502916'],
#  'Manual Test Coverage': ['1203934098501466'],
#  'Pre-Condition': '已經進入病患清單並使用過個人memo功能',
#  'Test Step': '1. 回到病患清單\n2. 再次進入該病人的個人memo\n3. 點選存回舊系統/完成看診\n4. 再次進入該病人的個人memo\n5. 點選全院memo\n6. 再點回個人memo',
#  'Expected Result': '1. 回到病患清單\n2. 個人memo還在\n3. 存回舊系統/完成看診成功且個人memo仍在\n4. 個人memo文字未消失，功能正常\n5. 可以進入全院memo\n6. 再次進入個人memo，文字未消失，功能正常',
#  'Manual Test Environment': '1203926363806262',
#  'Case Source': '1203964893025997',
#  'MainTicket': 'https://app.asana.com/0/1201610634708103/1203751583595248/f',
#  'Generated By': '1204352561007625'}

# %%
fields
# Out:
# {'Effort': {'type': 'number'},
#  'CaseSuite': {'enum_options': {'即檢及列印': '1204387003439606',
#    '身分設定': '1203934098502916',
#    'SOAP': '1203934098502998',
#    '下診斷ICD': '1203934098503008',
#    '藥囑': '1203934098503062',
#    '醫囑': '1203934098502921',
#    '歷史病歷': '1203934098502962',
#    '稽核Rule': '1203934098503027',
#    '報告查詢': '1203934098502976',
#    '套餐(醫療)': '1203934098502991',
#    '就診明細': '1204466983046954',
#    '完成看診': '1203934098502834',
#    '身體數據': '1203934098502941',
#    '健保雲端': '1203934098502936',
#    '暫存及存回舊系統': '1204278087004936',
#    '清空看診資料(病歷維護)': '1204278011832310',
#    '健保卡及醫事卡': '1204124924017144',
#    '病患清單': '1203934098502908',
#    'Login': '1203934098502854',
#    'CPOE': '1204150600824431',
#    '院內公告': '1203934098502865',
#    '過敏及不良反應': '1203934098502956',
#    '列印': '1203934098502933',
#    '問卷': '1203934098502945',
#    '轉診': '1203934098502953',
#    'LifeCycle': '1203934098502860',
#    '環境設備': '1203934098502835',
#    '手術': '1203934098502965',
#    '電子表單': '1203934098502988',
#    '系統交互': '1203934098503005',
#    '電子病歷': '1203934098503248',
#    '疫苗': '1203934098503013',
#    '偕同編輯': '1203934098503070',
#    '掛號': '1203934098503072',
#    'DataSyc': '1203934098503076',
#    '再次完成看診': '1203934098503081',
#    '癌症相關': '1203934098503238',
#    '災難復原測試': '1203943007360272',
#    '架構及技術': '1203964893026037',
#    '個案管理': '1204161832030784',
#    '批價帳務': '1204172009992256',
#    '保險申報': '1204172009992257',
#    '其他': '1203934098503078',
#    'UI': '1204437681145655'},
#   'type': 'multi_enum'},
#  'Manual Test Coverage': {'enum_options': {'Smoke': '1203934098501464',
#    'Quick': '1203934098501465',
#    'Partial': '1203934098501466',
#    'Full': '1203934098501467',
#    'Backlog': '1203934098501469',
#    'DefectVerify': '1204124924017134',
#    'FectureVerify': '1204161832030785',
#    'E2E': '1204222443390009',
#    'Use Case': '1204222443390010',
#    'Offline': '1203943007360270'},
#   'type': 'multi_enum'},
#  'Manual Test Priority': {'enum_options': {'High': '1204395740629736',
#    'Medium': '1204395740629737',
#    'Low': '1204395740629738'},
#   'type': 'enum'},
#  'Pre-Condition': {'type': 'text'},
#  'Test Step': {'type': 'text'},
#  'Expected Result': {'type': 'text'},
#  'Post-Condition': {'type': 'text'},
#  'xRelease': {'enum_options': {'v.next Hotfix': '1204191076977825',
#    'v.next Feature': '1204191215556915',
#    'XRT0011W': '1204370943928676',
#    'XRT0010H': '1204370943928675',
#    'XRT0009W': '1204256012972448',
#    'XRT0008H': '1204213162513273',
#    'XRT0007W': '1204151393723066',
#    'XRT0006H': '1204151393723067',
#    'XRT0005H': '1204190912755613',
#    'XRT0004W': '1204190396223455'},
#   'type': 'multi_enum'},
#  'Manual Test Date': {'type': 'date'},
#  'Manual Test Environment': {'enum_options': {'INTT': '1203926363806261',
#    'STAGE': '1203926363806262',
#    'PROD': '1203926363806263',
#    'DEV': '1204305354230536'},
#   'type': 'enum'},
#  'Manual Test Result': {'enum_options': {'Testing': '1204278011832321',
#    'Passed': '1203926363806256',
#    'Failed': '1203926363806257',
#    'Triage': '1203926363806258',
#    'Pass with Note': '1204447833841095'},
#   'type': 'enum'},
#  'Manual Test Comment': {'type': 'text'},
#  'Role': {'enum_options': {'醫師': '1203880512051790',
#    '跟診': '1203880512051791',
#    '二線科人員': '1203880512051798',
#    '藥師': '1203880512051792',
#    '營養師': '1203880512051793',
#    'ALL': '1203954415389020'},
#   'type': 'multi_enum'},
#  'Case Source': {'enum_options': {'PRD': '1203964893025996',
#    'Defect': '1203964893025997',
#    'Testing': '1203964893025998',
#    'ETC': '1203964893025999',
#    'CR': '1204203317450647',
#    'E2E': '1204222443390006',
#    'Use Case': '1204222443390007',
#    'Acceptance Criteria': '1204222443390008'},
#   'type': 'enum'},
#  'PRD': {'type': 'text'},
#  'MainTicket': {'type': 'text'},
#  'Non-xHIS': {'enum_options': {'CC Module': '1203934098502869',
#    'CC Web': '1203934098502990',
#    'AICS SaaS': '1203946901342662',
#    'Third Party': '1203934098502870',
#    'Azure SaaS': '1203943007360274'},
#   'type': 'multi_enum'},
#  'Automation Assignee': {'type': 'people'},
#  'Automation Status': {'enum_options': {'Automated': '1204036362646081',
#    '進行中': '1204036362646082',
#    'Partially Automated': '1204124699309640',
#    'In Progress': '1204115697181473',
#    '待討論': '1204036364493279',
#    'To Automate': '1204115697181474',
#    'Manual': '1204234906053321',
#    'TBD': '1204234733879588'},
#   'type': 'enum'},
#  'Automation ID': {'type': 'text'},
#  'Automation Comments': {'type': 'text'},
#  'Generated By': {'enum_options': {'Human': '1204352561007624',
#    'gpt-3.5-turbo': '1204352561007625'},
#   'type': 'enum'},
#  'Prompt Token': {'type': 'number'},
#  'Completion Token': {'type': 'number'},
#  'Total Token': {'type': 'number'},
#  'Incur Time Cost': {'type': 'text'}}

# %%
custom_field_data = {
    "CaseSuite": formData['caseSuite'],
    "Manual Test Coverage": formData["manualTestCoverage"],
    "Case Source": formData['caseSource'],
    "Generated By": formData['generatedBy'],
    "MainTicket": formData['mainTicket'],
    "Manual Test Environment": formData['manualTestEnvironment'],
    "Pre-Condition": formData['preCondition'],
    "Test Step": formData['testStep'],
    "Expected Result": formData['expectedResult'],
}

# %%
custom_fields
# Out:
# {'CaseSuite': ['1203934098503078', '1203934098502916'],
#  'Manual Test Coverage': ['1203934098501466'],
#  'Pre-Condition': '已經進入病患清單並使用過個人memo功能',
#  'Test Step': '1. 回到病患清單\n2. 再次進入該病人的個人memo\n3. 點選存回舊系統/完成看診\n4. 再次進入該病人的個人memo\n5. 點選全院memo\n6. 再點回個人memo',
#  'Expected Result': '1. 回到病患清單\n2. 個人memo還在\n3. 存回舊系統/完成看診成功且個人memo仍在\n4. 個人memo文字未消失，功能正常\n5. 可以進入全院memo\n6. 再次進入個人memo，文字未消失，功能正常',
#  'Manual Test Environment': '1203926363806262',
#  'Case Source': '1203964893025997',
#  'MainTicket': 'https://app.asana.com/0/1201610634708103/1203751583595248/f',
#  'Generated By': '1204352561007625'}

# %%
custom_fields = {}
for field_name, field_options in fields.items():
    field_type = field_options.get('type')
    if not (custom_field_data.get(field_name)):
        continue
    print(field_name)
    print(field_type)
    if field_type == 'enum':
        # Get the gid of the enum option
        enum_gid = field_options['enum_options'].get(custom_field_data.get(field_name))
        print(enum_gid)
        if enum_gid:
            custom_fields[field_name] = enum_gid
    elif field_type == 'multi_enum':
        # Get the gids of the multi-enum options
        if type(custom_field_data.get(field_name))==str:
            multi_enum_values = [field_options['enum_options'].get(custom_field_data.get(field_name))]
        elif custom_field_data.get(field_name)==None:
            multi_enum_values = None
        else:
            multi_enum_values = [field_options['enum_options'][name] for name in custom_field_data.get(field_name)]
        print(multi_enum_values)
        if multi_enum_values:
            custom_fields[field_name] =  multi_enum_values
    else:
        # Assume it's a text field
        text_value = custom_field_data.get(field_name)
        if text_value:
            custom_fields[field_name] = text_value
# Out:
# CaseSuite
# multi_enum
# ['1203934098503078', '1203934098502916']
# Manual Test Coverage
# multi_enum
# ['1203934098501466']
# Pre-Condition
# text
# Test Step
# text
# Expected Result
# text
# Manual Test Environment
# enum
# 1203926363806262
# Case Source
# enum
# 1203964893025997
# MainTicket
# text
# Generated By
# enum
# 1204352561007625

# %%
custom_fields
# Out:
# {'CaseSuite': {'text_value': ['其他', '身分設定']},
#  'Manual Test Coverage': {'text_value': 'Partial'},
#  'Manual Test Environment': {'text_value': 'STAGE'},
#  'Case Source': {'text_value': 'Defect'},
#  'Generated By': {'text_value': 'gpt-3.5-turbo'}}

# %%
fields_gid = {}
for item in result['data']:
    fields_gid[item['custom_field']['name']] = item['custom_field']['gid']

# %%
custom_field_data =

# %%
custom_field_data
# Out:
# {'1203934098502833': {'multi_enum_values': ['其他', '身分設定']},
#  '1203934098501463': {'multi_enum_values': 'Partial'},
#  '1203964893025995': {'enum_value': 'Defect'},
#  '1204352561007623': {'enum_value': 'gpt-3.5-turbo'},
#  '1203965600326165': {'text_value': 'https://app.asana.com/0/1201610634708103/1203751583595248/f'},
#  '1203926363806260': {'enum_value': 'STAGE'},
#  '1203889479039598': {'text_value': '已經進入病患清單並使用過個人memo功能'},
#  '1203880492084985': {'text_value': '1. 回到病患清單\n2. 再次進入該病人的個人memo\n3. 點選存回舊系統/完成看診\n4. 再次進入該病人的個人memo\n5. 點選全院memo\n6. 再點回個人memo'},
#  '1203880492084987': {'text_value': '1. 回到病患清單\n2. 個人memo還在\n3. 存回舊系統/完成看診成功且個人memo仍在\n4. 個人memo文字未消失，功能正常\n5. 可以進入全院memo\n6. 再次進入個人memo，文字未消失，功能正常'}}

# %%
custom_fields_final= {
        fields_gid["CaseSuite"]:  custom_fields['CaseSuite'],
        fields_gid["Manual Test Coverage"]: custom_fields["Manual Test Coverage"],
        fields_gid["Case Source"]:  custom_fields['Case Source'],
        fields_gid["Generated By"]:  custom_fields['Generated By'],
        fields_gid["MainTicket"]: custom_fields['MainTicket'],
        fields_gid["Manual Test Environment"]: custom_fields['Manual Test Environment'],
        fields_gid["Pre-Condition"]:  custom_fields['Pre-Condition'],
        fields_gid["Test Step"]:  custom_fields['Test Step'],
        fields_gid["Expected Result"]: custom_fields['Expected Result'],
    }

# %%
custom_fields_final
# Out:
# {'1203934098502833': ['1203934098503078', '1203934098502916'],
#  '1203934098501463': ['1203934098501466'],
#  '1203964893025995': '1203964893025997',
#  '1204352561007623': '1204352561007625',
#  '1203965600326165': 'https://app.asana.com/0/1201610634708103/1203751583595248/f',
#  '1203926363806260': '1203926363806262',
#  '1203889479039598': '已經進入病患清單並使用過個人memo功能',
#  '1203880492084985': '1. 回到病患清單\n2. 再次進入該病人的個人memo\n3. 點選存回舊系統/完成看診\n4. 再次進入該病人的個人memo\n5. 點選全院memo\n6. 再點回個人memo',
#  '1203880492084987': '1. 回到病患清單\n2. 個人memo還在\n3. 存回舊系統/完成看診成功且個人memo仍在\n4. 個人memo文字未消失，功能正常\n5. 可以進入全院memo\n6. 再次進入個人memo，文字未消失，功能正常'}

# %%
fields_gid
# Out:
# {'Effort': '1203880492084953',
#  'CaseSuite': '1203934098502833',
#  'Manual Test Coverage': '1203934098501463',
#  'Manual Test Priority': '1204395740629735',
#  'Pre-Condition': '1203889479039598',
#  'Test Step': '1203880492084985',
#  'Expected Result': '1203880492084987',
#  'Post-Condition': '1203927944090616',
#  'xRelease': '1204151393723065',
#  'Manual Test Date': '1203926363806253',
#  'Manual Test Environment': '1203926363806260',
#  'Manual Test Result': '1203926363806255',
#  'Manual Test Comment': '1203954415389068',
#  'Role': '1203880512051789',
#  'Case Source': '1203964893025995',
#  'PRD': '1203889479039580',
#  'MainTicket': '1203965600326165',
#  'Non-xHIS': '1203934098502868',
#  'Automation Assignee': '1204483792823835',
#  'Automation Status': '1204036362646080',
#  'Automation ID': '1204115697181482',
#  'Automation Comments': '1204115697181484',
#  'Generated By': '1204352561007623',
#  'Prompt Token': '1204352561007629',
#  'Completion Token': '1204352561007631',
#  'Total Token': '1204352561007638',
#  'Incur Time Cost': '1204352561007633'}

# %%
fields_gid["CaseSuite"]
# Out:
# '1203934098502833'

# %%
custom_field_data = {
        fields_gid["CaseSuite"]:  custom_field_data['caseSuite'],
        fields_gid["Manual Test Coverage"]: custom_field_data["manualTestCoverage"],
        fields_gid["Case Source"]:  {"enum_value": custom_field_data['caseSource']},
        fields_gid["Generated By"]:  {"enum_value": custom_field_data['generatedBy']},
        fields_gid["MainTicket"]: {"text_value": custom_field_data['mainTicket']},
        fields_gid["Manual Test Environment"]:  {"enum_value": custom_field_data['manualTestEnvironment']},
        fields_gid["Pre-Condition"]:  {"text_value": custom_field_data['preCondition']},
        fields_gid["Test Step"]:  {"text_value": custom_field_data['testStep']},
        fields_gid["Expected Result"]:  {"text_value": custom_field_data['expectedResult']},
    }
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/kuoyihsin/My Drive/2工作/AICS/InDev/GPT-testCase-Generator/asana.ipynb Cell 23 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/kuoyihsin/My%20Drive/2%E5%B7%A5%E4%BD%9C/AICS/InDev/GPT-testCase-Generator/asana.ipynb#Y106sZmlsZQ%3D%3D?line=0'>1</a> custom_field_data = {
# ----> <a href='vscode-notebook-cell:/Users/kuoyihsin/My%20Drive/2%E5%B7%A5%E4%BD%9C/AICS/InDev/GPT-testCase-Generator/asana.ipynb#Y106sZmlsZQ%3D%3D?line=1'>2</a>         fields_gid["CaseSuite"]:  custom_field_data['caseSuite'],
#       <a href='vscode-notebook-cell:/Users/kuoyihsin/My%20Drive/2%E5%B7%A5%E4%BD%9C/AICS/InDev/GPT-testCase-Generator/asana.ipynb#Y106sZmlsZQ%3D%3D?line=2'>3</a>         fields_gid["Manual Test Coverage"]: custom_field_data["manualTestCoverage"],
#       <a href='vscode-notebook-cell:/Users/kuoyihsin/My%20Drive/2%E5%B7%A5%E4%BD%9C/AICS/InDev/GPT-testCase-Generator/asana.ipynb#Y106sZmlsZQ%3D%3D?line=3'>4</a>         fields_gid["Case Source"]:  {"enum_value": custom_field_data['caseSource']},
#       <a href='vscode-notebook-cell:/Users/kuoyihsin/My%20Drive/2%E5%B7%A5%E4%BD%9C/AICS/InDev/GPT-testCase-Generator/asana.ipynb#Y106sZmlsZQ%3D%3D?line=4'>5</a>         fields_gid["Generated By"]:  {"enum_value": custom_field_data['generatedBy']},
#       <a href='vscode-notebook-cell:/Users/kuoyihsin/My%20Drive/2%E5%B7%A5%E4%BD%9C/AICS/InDev/GPT-testCase-Generator/asana.ipynb#Y106sZmlsZQ%3D%3D?line=5'>6</a>         fields_gid["MainTicket"]: {"text_value": custom_field_data['mainTicket']},
#       <a href='vscode-notebook-cell:/Users/kuoyihsin/My%20Drive/2%E5%B7%A5%E4%BD%9C/AICS/InDev/GPT-testCase-Generator/asana.ipynb#Y106sZmlsZQ%3D%3D?line=6'>7</a>         fields_gid["Manual Test Environment"]:  {"enum_value": custom_field_data['manualTestEnvironment']},
#       <a href='vscode-notebook-cell:/Users/kuoyihsin/My%20Drive/2%E5%B7%A5%E4%BD%9C/AICS/InDev/GPT-testCase-Generator/asana.ipynb#Y106sZmlsZQ%3D%3D?line=7'>8</a>         fields_gid["Pre-Condition"]:  {"text_value": custom_field_data['preCondition']},
#       <a href='vscode-notebook-cell:/Users/kuoyihsin/My%20Drive/2%E5%B7%A5%E4%BD%9C/AICS/InDev/GPT-testCase-Generator/asana.ipynb#Y106sZmlsZQ%3D%3D?line=8'>9</a>         fields_gid["Test Step"]:  {"text_value": custom_field_data['testStep']},
#      <a href='vscode-notebook-cell:/Users/kuoyihsin/My%20Drive/2%E5%B7%A5%E4%BD%9C/AICS/InDev/GPT-testCase-Generator/asana.ipynb#Y106sZmlsZQ%3D%3D?line=9'>10</a>         fields_gid["Expected Result"]:  {"text_value": custom_field_data['expectedResult']},
#      <a href='vscode-notebook-cell:/Users/kuoyihsin/My%20Drive/2%E5%B7%A5%E4%BD%9C/AICS/InDev/GPT-testCase-Generator/asana.ipynb#Y106sZmlsZQ%3D%3D?line=10'>11</a>     }
#
# KeyError: 'caseSuite'

# %%
fields
# Out:
# {'CaseSuite': {'enum_options': {'即檢及列印': '1204387003439606',
#    '身分設定': '1203934098502916',
#    'SOAP': '1203934098502998',
#    '下診斷ICD': '1203934098503008',
#    '藥囑': '1203934098503062',
#    '醫囑': '1203934098502921',
#    '歷史病歷': '1203934098502962',
#    '稽核Rule': '1203934098503027',
#    '報告查詢': '1203934098502976',
#    '套餐(醫療)': '1203934098502991',
#    '就診明細': '1204466983046954',
#    '完成看診': '1203934098502834',
#    '身體數據': '1203934098502941',
#    '健保雲端': '1203934098502936',
#    '暫存及存回舊系統': '1204278087004936',
#    '清空看診資料(病歷維護)': '1204278011832310',
#    '健保卡及醫事卡': '1204124924017144',
#    '病患清單': '1203934098502908',
#    'Login': '1203934098502854',
#    'CPOE': '1204150600824431',
#    '院內公告': '1203934098502865',
#    '過敏及不良反應': '1203934098502956',
#    '列印': '1203934098502933',
#    '問卷': '1203934098502945',
#    '轉診': '1203934098502953',
#    'LifeCycle': '1203934098502860',
#    '環境設備': '1203934098502835',
#    '手術': '1203934098502965',
#    '電子表單': '1203934098502988',
#    '系統交互': '1203934098503005',
#    '電子病歷': '1203934098503248',
#    '疫苗': '1203934098503013',
#    '偕同編輯': '1203934098503070',
#    '掛號': '1203934098503072',
#    'DataSyc': '1203934098503076',
#    '再次完成看診': '1203934098503081',
#    '癌症相關': '1203934098503238',
#    '災難復原測試': '1203943007360272',
#    '架構及技術': '1203964893026037',
#    '個案管理': '1204161832030784',
#    '批價帳務': '1204172009992256',
#    '保險申報': '1204172009992257',
#    '其他': '1203934098503078',
#    'UI': '1204437681145655'}},
#  'Manual Test Coverage': {'enum_options': {'Smoke': '1203934098501464',
#    'Quick': '1203934098501465',
#    'Partial': '1203934098501466',
#    'Full': '1203934098501467',
#    'Backlog': '1203934098501469',
#    'DefectVerify': '1204124924017134',
#    'FectureVerify': '1204161832030785',
#    'E2E': '1204222443390009',
#    'Use Case': '1204222443390010',
#    'Offline': '1203943007360270'}},
#  'Manual Test Priority': {'enum_options': {'High': '1204395740629736',
#    'Medium': '1204395740629737',
#    'Low': '1204395740629738'}},
#  'xRelease': {'enum_options': {'v.next Hotfix': '1204191076977825',
#    'v.next Feature': '1204191215556915',
#    'XRT0011W': '1204370943928676',
#    'XRT0010H': '1204370943928675',
#    'XRT0009W': '1204256012972448',
#    'XRT0008H': '1204213162513273',
#    'XRT0007W': '1204151393723066',
#    'XRT0006H': '1204151393723067',
#    'XRT0005H': '1204190912755613',
#    'XRT0004W': '1204190396223455'}},
#  'Manual Test Environment': {'enum_options': {'INTT': '1203926363806261',
#    'STAGE': '1203926363806262',
#    'PROD': '1203926363806263',
#    'DEV': '1204305354230536'}},
#  'Manual Test Result': {'enum_options': {'Testing': '1204278011832321',
#    'Passed': '1203926363806256',
#    'Failed': '1203926363806257',
#    'Triage': '1203926363806258',
#    'Pass with Note': '1204447833841095'}},
#  'Role': {'enum_options': {'醫師': '1203880512051790',
#    '跟診': '1203880512051791',
#    '二線科人員': '1203880512051798',
#    '藥師': '1203880512051792',
#    '營養師': '1203880512051793',
#    'ALL': '1203954415389020'}},
#  'Case Source': {'enum_options': {'PRD': '1203964893025996',
#    'Defect': '1203964893025997',
#    'Testing': '1203964893025998',
#    'ETC': '1203964893025999',
#    'CR': '1204203317450647',
#    'E2E': '1204222443390006',
#    'Use Case': '1204222443390007',
#    'Acceptance Criteria': '1204222443390008'}},
#  'Non-xHIS': {'enum_options': {'CC Module': '1203934098502869',
#    'CC Web': '1203934098502990',
#    'AICS SaaS': '1203946901342662',
#    'Third Party': '1203934098502870',
#    'Azure SaaS': '1203943007360274'}},
#  'Automation Status': {'enum_options': {'Automated': '1204036362646081',
#    '進行中': '1204036362646082',
#    'Partially Automated': '1204124699309640',
#    'In Progress': '1204115697181473',
#    '待討論': '1204036364493279',
#    'To Automate': '1204115697181474',
#    'Manual': '1204234906053321',
#    'TBD': '1204234733879588'}},
#  'Generated By': {'enum_options': {'Human': '1204352561007624',
#    'gpt-3.5-turbo': '1204352561007625'}}}

# %%
result
# Out:
# {'data': [{'gid': '1203880492084954',
#    'custom_field': {'gid': '1203880492084953',
#     'name': 'Effort',
#     'precision': 0,
#     'resource_subtype': 'number',
#     'resource_type': 'custom_field',
#     'type': 'number'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1203934098502836',
#    'custom_field': {'gid': '1203934098502833',
#     'enum_options': [{'gid': '1204387003439606',
#       'color': 'hot-pink',
#       'enabled': True,
#       'name': '即檢及列印',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502916',
#       'color': 'blue-green',
#       'enabled': True,
#       'name': '身分設定',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502998',
#       'color': 'yellow',
#       'enabled': True,
#       'name': 'SOAP',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098503008',
#       'color': 'green',
#       'enabled': True,
#       'name': '下診斷ICD',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098503062',
#       'color': 'pink',
#       'enabled': True,
#       'name': '藥囑',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502921',
#       'color': 'orange',
#       'enabled': True,
#       'name': '醫囑',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502962',
#       'color': 'cool-gray',
#       'enabled': True,
#       'name': '歷史病歷',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098503027',
#       'color': 'hot-pink',
#       'enabled': True,
#       'name': '稽核Rule',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502976',
#       'color': 'none',
#       'enabled': True,
#       'name': '報告查詢',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502991',
#       'color': 'none',
#       'enabled': True,
#       'name': '套餐(醫療)',
#       'resource_type': 'enum_option'},
#      {'gid': '1204466983046954',
#       'color': 'none',
#       'enabled': True,
#       'name': '就診明細',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502834',
#       'color': 'green',
#       'enabled': True,
#       'name': '完成看診',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502941',
#       'color': 'purple',
#       'enabled': True,
#       'name': '身體數據',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502936',
#       'color': 'indigo',
#       'enabled': True,
#       'name': '健保雲端',
#       'resource_type': 'enum_option'},
#      {'gid': '1204278087004936',
#       'color': 'aqua',
#       'enabled': True,
#       'name': '暫存及存回舊系統',
#       'resource_type': 'enum_option'},
#      {'gid': '1204278011832310',
#       'color': 'yellow-orange',
#       'enabled': True,
#       'name': '清空看診資料(病歷維護)',
#       'resource_type': 'enum_option'},
#      {'gid': '1204124924017144',
#       'color': 'none',
#       'enabled': True,
#       'name': '健保卡及醫事卡',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502908',
#       'color': 'yellow-green',
#       'enabled': True,
#       'name': '病患清單',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502854',
#       'color': 'orange',
#       'enabled': True,
#       'name': 'Login',
#       'resource_type': 'enum_option'},
#      {'gid': '1204150600824431',
#       'color': 'orange',
#       'enabled': True,
#       'name': 'CPOE',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502865',
#       'color': 'yellow',
#       'enabled': True,
#       'name': '院內公告',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502956',
#       'color': 'pink',
#       'enabled': True,
#       'name': '過敏及不良反應',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502933',
#       'color': 'blue',
#       'enabled': True,
#       'name': '列印',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502945',
#       'color': 'magenta',
#       'enabled': True,
#       'name': '問卷',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502953',
#       'color': 'hot-pink',
#       'enabled': True,
#       'name': '轉診',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502860',
#       'color': 'yellow-orange',
#       'enabled': True,
#       'name': 'LifeCycle',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502835',
#       'color': 'red',
#       'enabled': True,
#       'name': '環境設備',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502965',
#       'color': 'none',
#       'enabled': True,
#       'name': '手術',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502988',
#       'color': 'none',
#       'enabled': True,
#       'name': '電子表單',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098503005',
#       'color': 'none',
#       'enabled': True,
#       'name': '系統交互',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098503248',
#       'color': 'none',
#       'enabled': True,
#       'name': '電子病歷',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098503013',
#       'color': 'none',
#       'enabled': True,
#       'name': '疫苗',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098503070',
#       'color': 'none',
#       'enabled': True,
#       'name': '偕同編輯',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098503072',
#       'color': 'none',
#       'enabled': True,
#       'name': '掛號',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098503076',
#       'color': 'none',
#       'enabled': True,
#       'name': 'DataSyc',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098503081',
#       'color': 'none',
#       'enabled': True,
#       'name': '再次完成看診',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098503238',
#       'color': 'none',
#       'enabled': True,
#       'name': '癌症相關',
#       'resource_type': 'enum_option'},
#      {'gid': '1203943007360272',
#       'color': 'none',
#       'enabled': True,
#       'name': '災難復原測試',
#       'resource_type': 'enum_option'},
#      {'gid': '1203964893026037',
#       'color': 'none',
#       'enabled': True,
#       'name': '架構及技術',
#       'resource_type': 'enum_option'},
#      {'gid': '1204161832030784',
#       'color': 'none',
#       'enabled': True,
#       'name': '個案管理',
#       'resource_type': 'enum_option'},
#      {'gid': '1204172009992256',
#       'color': 'none',
#       'enabled': True,
#       'name': '批價帳務',
#       'resource_type': 'enum_option'},
#      {'gid': '1204172009992257',
#       'color': 'none',
#       'enabled': True,
#       'name': '保險申報',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098503078',
#       'color': 'none',
#       'enabled': True,
#       'name': '其他',
#       'resource_type': 'enum_option'},
#      {'gid': '1204437681145655',
#       'color': 'none',
#       'enabled': True,
#       'name': 'UI',
#       'resource_type': 'enum_option'}],
#     'name': 'CaseSuite',
#     'resource_subtype': 'multi_enum',
#     'resource_type': 'custom_field',
#     'type': 'multi_enum'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1203934098501468',
#    'custom_field': {'gid': '1203934098501463',
#     'enum_options': [{'gid': '1203934098501464',
#       'color': 'red',
#       'enabled': True,
#       'name': 'Smoke',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098501465',
#       'color': 'green',
#       'enabled': True,
#       'name': 'Quick',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098501466',
#       'color': 'indigo',
#       'enabled': True,
#       'name': 'Partial',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098501467',
#       'color': 'yellow-orange',
#       'enabled': True,
#       'name': 'Full',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098501469',
#       'color': 'cool-gray',
#       'enabled': False,
#       'name': 'Backlog',
#       'resource_type': 'enum_option'},
#      {'gid': '1204124924017134',
#       'color': 'yellow',
#       'enabled': False,
#       'name': 'DefectVerify',
#       'resource_type': 'enum_option'},
#      {'gid': '1204161832030785',
#       'color': 'yellow-green',
#       'enabled': False,
#       'name': 'FectureVerify',
#       'resource_type': 'enum_option'},
#      {'gid': '1204222443390009',
#       'color': 'blue-green',
#       'enabled': False,
#       'name': 'E2E',
#       'resource_type': 'enum_option'},
#      {'gid': '1204222443390010',
#       'color': 'aqua',
#       'enabled': False,
#       'name': 'Use Case',
#       'resource_type': 'enum_option'},
#      {'gid': '1203943007360270',
#       'color': 'orange',
#       'enabled': True,
#       'name': 'Offline',
#       'resource_type': 'enum_option'}],
#     'name': 'Manual Test Coverage',
#     'resource_subtype': 'multi_enum',
#     'resource_type': 'custom_field',
#     'type': 'multi_enum'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1204395740629740',
#    'custom_field': {'gid': '1204395740629735',
#     'enum_options': [{'gid': '1204395740629736',
#       'color': 'red',
#       'enabled': True,
#       'name': 'High',
#       'resource_type': 'enum_option'},
#      {'gid': '1204395740629737',
#       'color': 'orange',
#       'enabled': True,
#       'name': 'Medium',
#       'resource_type': 'enum_option'},
#      {'gid': '1204395740629738',
#       'color': 'yellow-orange',
#       'enabled': True,
#       'name': 'Low',
#       'resource_type': 'enum_option'}],
#     'name': 'Manual Test Priority',
#     'resource_subtype': 'enum',
#     'resource_type': 'custom_field',
#     'type': 'enum'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1203889479039599',
#    'custom_field': {'gid': '1203889479039598',
#     'name': 'Pre-Condition',
#     'resource_subtype': 'text',
#     'resource_type': 'custom_field',
#     'type': 'text'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1203880492084986',
#    'custom_field': {'gid': '1203880492084985',
#     'name': 'Test Step',
#     'resource_subtype': 'text',
#     'resource_type': 'custom_field',
#     'type': 'text'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1203880492084988',
#    'custom_field': {'gid': '1203880492084987',
#     'name': 'Expected Result',
#     'resource_subtype': 'text',
#     'resource_type': 'custom_field',
#     'type': 'text'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1203927944090617',
#    'custom_field': {'gid': '1203927944090616',
#     'name': 'Post-Condition',
#     'resource_subtype': 'text',
#     'resource_type': 'custom_field',
#     'type': 'text'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1204446526756500',
#    'custom_field': {'gid': '1204151393723065',
#     'enum_options': [{'gid': '1204191076977825',
#       'color': 'red',
#       'enabled': True,
#       'name': 'v.next Hotfix',
#       'resource_type': 'enum_option'},
#      {'gid': '1204191215556915',
#       'color': 'red',
#       'enabled': True,
#       'name': 'v.next Feature',
#       'resource_type': 'enum_option'},
#      {'gid': '1204370943928676',
#       'color': 'none',
#       'enabled': True,
#       'name': 'XRT0011W',
#       'resource_type': 'enum_option'},
#      {'gid': '1204370943928675',
#       'color': 'none',
#       'enabled': True,
#       'name': 'XRT0010H',
#       'resource_type': 'enum_option'},
#      {'gid': '1204256012972448',
#       'color': 'none',
#       'enabled': True,
#       'name': 'XRT0009W',
#       'resource_type': 'enum_option'},
#      {'gid': '1204213162513273',
#       'color': 'none',
#       'enabled': True,
#       'name': 'XRT0008H',
#       'resource_type': 'enum_option'},
#      {'gid': '1204151393723066',
#       'color': 'none',
#       'enabled': True,
#       'name': 'XRT0007W',
#       'resource_type': 'enum_option'},
#      {'gid': '1204151393723067',
#       'color': 'none',
#       'enabled': True,
#       'name': 'XRT0006H',
#       'resource_type': 'enum_option'},
#      {'gid': '1204190912755613',
#       'color': 'none',
#       'enabled': True,
#       'name': 'XRT0005H',
#       'resource_type': 'enum_option'},
#      {'gid': '1204190396223455',
#       'color': 'none',
#       'enabled': True,
#       'name': 'XRT0004W',
#       'resource_type': 'enum_option'}],
#     'name': 'xRelease',
#     'resource_subtype': 'multi_enum',
#     'resource_type': 'custom_field',
#     'type': 'multi_enum'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1203926363806254',
#    'custom_field': {'gid': '1203926363806253',
#     'name': 'Manual Test Date',
#     'resource_subtype': 'date',
#     'resource_type': 'custom_field',
#     'type': 'date'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1203926363806264',
#    'custom_field': {'gid': '1203926363806260',
#     'enum_options': [{'gid': '1203926363806261',
#       'color': 'yellow-green',
#       'enabled': True,
#       'name': 'INTT',
#       'resource_type': 'enum_option'},
#      {'gid': '1203926363806262',
#       'color': 'purple',
#       'enabled': True,
#       'name': 'STAGE',
#       'resource_type': 'enum_option'},
#      {'gid': '1203926363806263',
#       'color': 'blue',
#       'enabled': True,
#       'name': 'PROD',
#       'resource_type': 'enum_option'},
#      {'gid': '1204305354230536',
#       'color': 'red',
#       'enabled': True,
#       'name': 'DEV',
#       'resource_type': 'enum_option'}],
#     'name': 'Manual Test Environment',
#     'resource_subtype': 'enum',
#     'resource_type': 'custom_field',
#     'type': 'enum'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1203926363806259',
#    'custom_field': {'gid': '1203926363806255',
#     'enum_options': [{'gid': '1204278011832321',
#       'color': 'yellow',
#       'enabled': True,
#       'name': 'Testing',
#       'resource_type': 'enum_option'},
#      {'gid': '1203926363806256',
#       'color': 'green',
#       'enabled': True,
#       'name': 'Passed',
#       'resource_type': 'enum_option'},
#      {'gid': '1203926363806257',
#       'color': 'red',
#       'enabled': True,
#       'name': 'Failed',
#       'resource_type': 'enum_option'},
#      {'gid': '1203926363806258',
#       'color': 'hot-pink',
#       'enabled': True,
#       'name': 'Triage',
#       'resource_type': 'enum_option'},
#      {'gid': '1204447833841095',
#       'color': 'orange',
#       'enabled': True,
#       'name': 'Pass with Note',
#       'resource_type': 'enum_option'}],
#     'name': 'Manual Test Result',
#     'resource_subtype': 'enum',
#     'resource_type': 'custom_field',
#     'type': 'enum'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1203954415389069',
#    'custom_field': {'gid': '1203954415389068',
#     'name': 'Manual Test Comment',
#     'resource_subtype': 'text',
#     'resource_type': 'custom_field',
#     'type': 'text'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1203880512051794',
#    'custom_field': {'gid': '1203880512051789',
#     'enum_options': [{'gid': '1203880512051790',
#       'color': 'green',
#       'enabled': True,
#       'name': '醫師',
#       'resource_type': 'enum_option'},
#      {'gid': '1203880512051791',
#       'color': 'red',
#       'enabled': True,
#       'name': '跟診',
#       'resource_type': 'enum_option'},
#      {'gid': '1203880512051798',
#       'color': 'purple',
#       'enabled': True,
#       'name': '二線科人員',
#       'resource_type': 'enum_option'},
#      {'gid': '1203880512051792',
#       'color': 'orange',
#       'enabled': True,
#       'name': '藥師',
#       'resource_type': 'enum_option'},
#      {'gid': '1203880512051793',
#       'color': 'yellow-orange',
#       'enabled': True,
#       'name': '營養師',
#       'resource_type': 'enum_option'},
#      {'gid': '1203954415389020',
#       'color': 'yellow',
#       'enabled': True,
#       'name': 'ALL',
#       'resource_type': 'enum_option'}],
#     'name': 'Role',
#     'resource_subtype': 'multi_enum',
#     'resource_type': 'custom_field',
#     'type': 'multi_enum'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1203964893026000',
#    'custom_field': {'gid': '1203964893025995',
#     'enum_options': [{'gid': '1203964893025996',
#       'color': 'green',
#       'enabled': True,
#       'name': 'PRD',
#       'resource_type': 'enum_option'},
#      {'gid': '1203964893025997',
#       'color': 'red',
#       'enabled': True,
#       'name': 'Defect',
#       'resource_type': 'enum_option'},
#      {'gid': '1203964893025998',
#       'color': 'orange',
#       'enabled': True,
#       'name': 'Testing',
#       'resource_type': 'enum_option'},
#      {'gid': '1203964893025999',
#       'color': 'yellow-orange',
#       'enabled': True,
#       'name': 'ETC',
#       'resource_type': 'enum_option'},
#      {'gid': '1204203317450647',
#       'color': 'yellow',
#       'enabled': True,
#       'name': 'CR',
#       'resource_type': 'enum_option'},
#      {'gid': '1204222443390006',
#       'color': 'yellow-green',
#       'enabled': True,
#       'name': 'E2E',
#       'resource_type': 'enum_option'},
#      {'gid': '1204222443390007',
#       'color': 'blue-green',
#       'enabled': True,
#       'name': 'Use Case',
#       'resource_type': 'enum_option'},
#      {'gid': '1204222443390008',
#       'color': 'aqua',
#       'enabled': False,
#       'name': 'Acceptance Criteria',
#       'resource_type': 'enum_option'}],
#     'name': 'Case Source',
#     'resource_subtype': 'enum',
#     'resource_type': 'custom_field',
#     'type': 'enum'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1203889479039581',
#    'custom_field': {'gid': '1203889479039580',
#     'name': 'PRD',
#     'resource_subtype': 'text',
#     'resource_type': 'custom_field',
#     'type': 'text'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1203965600326166',
#    'custom_field': {'gid': '1203965600326165',
#     'name': 'MainTicket',
#     'resource_subtype': 'text',
#     'resource_type': 'custom_field',
#     'type': 'text'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1203934098502871',
#    'custom_field': {'gid': '1203934098502868',
#     'enum_options': [{'gid': '1203934098502869',
#       'color': 'green',
#       'enabled': True,
#       'name': 'CC Module',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502990',
#       'color': 'orange',
#       'enabled': True,
#       'name': 'CC Web',
#       'resource_type': 'enum_option'},
#      {'gid': '1203946901342662',
#       'color': 'yellow',
#       'enabled': True,
#       'name': 'AICS SaaS',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502870',
#       'color': 'red',
#       'enabled': True,
#       'name': 'Third Party',
#       'resource_type': 'enum_option'},
#      {'gid': '1203943007360274',
#       'color': 'yellow-orange',
#       'enabled': False,
#       'name': 'Azure SaaS',
#       'resource_type': 'enum_option'}],
#     'name': 'Non-xHIS',
#     'resource_subtype': 'multi_enum',
#     'resource_type': 'custom_field',
#     'type': 'multi_enum'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1204483792823836',
#    'custom_field': {'gid': '1204483792823835',
#     'name': 'Automation Assignee',
#     'resource_subtype': 'people',
#     'resource_type': 'custom_field',
#     'type': 'people'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1204036364493280',
#    'custom_field': {'gid': '1204036362646080',
#     'enum_options': [{'gid': '1204036362646081',
#       'color': 'green',
#       'enabled': True,
#       'name': 'Automated',
#       'resource_type': 'enum_option'},
#      {'gid': '1204036362646082',
#       'color': 'yellow',
#       'enabled': False,
#       'name': '進行中',
#       'resource_type': 'enum_option'},
#      {'gid': '1204124699309640',
#       'color': 'orange',
#       'enabled': True,
#       'name': 'Partially Automated',
#       'resource_type': 'enum_option'},
#      {'gid': '1204115697181473',
#       'color': 'yellow',
#       'enabled': True,
#       'name': 'In Progress',
#       'resource_type': 'enum_option'},
#      {'gid': '1204036364493279',
#       'color': 'orange',
#       'enabled': False,
#       'name': '待討論',
#       'resource_type': 'enum_option'},
#      {'gid': '1204115697181474',
#       'color': 'red',
#       'enabled': True,
#       'name': 'To Automate',
#       'resource_type': 'enum_option'},
#      {'gid': '1204234906053321',
#       'color': 'hot-pink',
#       'enabled': True,
#       'name': 'Manual',
#       'resource_type': 'enum_option'},
#      {'gid': '1204234733879588',
#       'color': 'blue',
#       'enabled': True,
#       'name': 'TBD',
#       'resource_type': 'enum_option'}],
#     'name': 'Automation Status',
#     'resource_subtype': 'enum',
#     'resource_type': 'custom_field',
#     'type': 'enum'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1204115697181483',
#    'custom_field': {'gid': '1204115697181482',
#     'name': 'Automation ID',
#     'resource_subtype': 'text',
#     'resource_type': 'custom_field',
#     'type': 'text'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1204115697181485',
#    'custom_field': {'gid': '1204115697181484',
#     'name': 'Automation Comments',
#     'resource_subtype': 'text',
#     'resource_type': 'custom_field',
#     'type': 'text'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1204352561007626',
#    'custom_field': {'gid': '1204352561007623',
#     'enum_options': [{'gid': '1204352561007624',
#       'color': 'green',
#       'enabled': True,
#       'name': 'Human',
#       'resource_type': 'enum_option'},
#      {'gid': '1204352561007625',
#       'color': 'red',
#       'enabled': True,
#       'name': 'gpt-3.5-turbo',
#       'resource_type': 'enum_option'}],
#     'name': 'Generated By',
#     'resource_subtype': 'enum',
#     'resource_type': 'custom_field',
#     'type': 'enum'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1204352561007630',
#    'custom_field': {'gid': '1204352561007629',
#     'name': 'Prompt Token',
#     'precision': 0,
#     'resource_subtype': 'number',
#     'resource_type': 'custom_field',
#     'type': 'number'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1204352561007632',
#    'custom_field': {'gid': '1204352561007631',
#     'name': 'Completion Token',
#     'precision': 0,
#     'resource_subtype': 'number',
#     'resource_type': 'custom_field',
#     'type': 'number'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1204352561007639',
#    'custom_field': {'gid': '1204352561007638',
#     'name': 'Total Token',
#     'precision': 0,
#     'resource_subtype': 'number',
#     'resource_type': 'custom_field',
#     'type': 'number'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1204352561007634',
#    'custom_field': {'gid': '1204352561007633',
#     'name': 'Incur Time Cost',
#     'resource_subtype': 'text',
#     'resource_type': 'custom_field',
#     'type': 'text'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'}]}

# %%
# Load environment variables from .env file
load_dotenv()

# Set up API key
ASANA_API_KEY = os.getenv('ASANA_API_KEY')
project_gid = '1201610634708103' # CCOPD
url = f"https://app.asana.com/api/1.0/projects/{project_gid}/custom_field_settings"

headers = {
    "Authorization": f"Bearer {ASANA_API_KEY}",
}

response = requests.get(url, headers=headers)
result = response.json()

# %%
needFields= ['xRelease']

# %%
result2 = client.custom_fields.get_custom_field('1204151393723065',  opt_pretty=True)
print(result2)
# Out:
# {'gid': '1204151393723065', 'enum_options': [{'gid': '1204191076977825', 'color': 'red', 'enabled': True, 'name': 'v.next Hotfix', 'resource_type': 'enum_option'}, {'gid': '1204191215556915', 'color': 'red', 'enabled': True, 'name': 'v.next Feature', 'resource_type': 'enum_option'}, {'gid': '1204370943928676', 'color': 'none', 'enabled': True, 'name': 'XRT0011W', 'resource_type': 'enum_option'}, {'gid': '1204370943928675', 'color': 'none', 'enabled': True, 'name': 'XRT0010H', 'resource_type': 'enum_option'}, {'gid': '1204256012972448', 'color': 'none', 'enabled': True, 'name': 'XRT0009W', 'resource_type': 'enum_option'}, {'gid': '1204213162513273', 'color': 'none', 'enabled': True, 'name': 'XRT0008H', 'resource_type': 'enum_option'}, {'gid': '1204151393723066', 'color': 'none', 'enabled': True, 'name': 'XRT0007W', 'resource_type': 'enum_option'}, {'gid': '1204151393723067', 'color': 'none', 'enabled': True, 'name': 'XRT0006H', 'resource_type': 'enum_option'}, {'gid': '1204190912755613', 'color': 'none', 'enabled': True, 'name': 'XRT0005H', 'resource_type': 'enum_option'}, {'gid': '1204190396223455', 'color': 'none', 'enabled': True, 'name': 'XRT0004W', 'resource_type': 'enum_option'}], 'name': 'xRelease', 'created_by': {'gid': '1146187112437384', 'name': 'Robert Lu', 'resource_type': 'user'}, 'resource_subtype': 'multi_enum', 'resource_type': 'custom_field', 'type': 'multi_enum', 'is_global_to_workspace': True, 'asana_created_field': None}

# %%
import requests

import asana

#task_gid =  "1203751583595248" # "1204117097732585"
task_gid = '1204483793307430'
custom_field_gid = '1204151393723065'# Replace with the gid of your custom field

ASANA_API_KEY = os.getenv('ASANA_API_KEY')

client = asana.Client.access_token(ASANA_API_KEY)

result = client.tasks.get_task(task_gid, opt_pretty=True, opt_fields=["Priority","custom_fields", "notes", "name", ])

needField = ['xRelease']

print(result)
# Out:
# {'gid': '1204483793307430', 'custom_fields': [{'gid': '1203880492084953', 'enabled': True, 'name': 'Effort', 'description': '分鐘數', 'number_value': 5, 'precision': 0, 'created_by': {'gid': '1203139226376547', 'name': 'Luke Hou', 'resource_type': 'user'}, 'display_value': '5', 'resource_subtype': 'number', 'resource_type': 'custom_field', 'type': 'number'}, {'gid': '1203934098502833', 'enabled': True, 'enum_options': [{'gid': '1204387003439606', 'color': 'hot-pink', 'enabled': True, 'name': '即檢及列印', 'resource_type': 'enum_option'}, {'gid': '1203934098502916', 'color': 'blue-green', 'enabled': True, 'name': '身分設定', 'resource_type': 'enum_option'}, {'gid': '1203934098502998', 'color': 'yellow', 'enabled': True, 'name': 'SOAP', 'resource_type': 'enum_option'}, {'gid': '1203934098503008', 'color': 'green', 'enabled': True, 'name': '下診斷ICD', 'resource_type': 'enum_option'}, {'gid': '1203934098503062', 'color': 'pink', 'enabled': True, 'name': '藥囑', 'resource_type': 'enum_option'}, {'gid': '1203934098502921', 'color': 'orange', 'enabled': True, 'name': '醫囑', 'resource_type': 'enum_option'}, {'gid': '1203934098502962', 'color': 'cool-gray', 'enabled': True, 'name': '歷史病歷', 'resource_type': 'enum_option'}, {'gid': '1203934098503027', 'color': 'hot-pink', 'enabled': True, 'name': '稽核Rule', 'resource_type': 'enum_option'}, {'gid': '1203934098502976', 'color': 'none', 'enabled': True, 'name': '報告查詢', 'resource_type': 'enum_option'}, {'gid': '1203934098502991', 'color': 'none', 'enabled': True, 'name': '套餐(醫療)', 'resource_type': 'enum_option'}, {'gid': '1204466983046954', 'color': 'none', 'enabled': True, 'name': '就診明細', 'resource_type': 'enum_option'}, {'gid': '1203934098502834', 'color': 'green', 'enabled': True, 'name': '完成看診', 'resource_type': 'enum_option'}, {'gid': '1203934098502941', 'color': 'purple', 'enabled': True, 'name': '身體數據', 'resource_type': 'enum_option'}, {'gid': '1203934098502936', 'color': 'indigo', 'enabled': True, 'name': '健保雲端', 'resource_type': 'enum_option'}, {'gid': '1204278087004936', 'color': 'aqua', 'enabled': True, 'name': '暫存及存回舊系統', 'resource_type': 'enum_option'}, {'gid': '1204278011832310', 'color': 'yellow-orange', 'enabled': True, 'name': '清空看診資料(病歷維護)', 'resource_type': 'enum_option'}, {'gid': '1204124924017144', 'color': 'none', 'enabled': True, 'name': '健保卡及醫事卡', 'resource_type': 'enum_option'}, {'gid': '1203934098502908', 'color': 'yellow-green', 'enabled': True, 'name': '病患清單', 'resource_type': 'enum_option'}, {'gid': '1203934098502854', 'color': 'orange', 'enabled': True, 'name': 'Login', 'resource_type': 'enum_option'}, {'gid': '1204150600824431', 'color': 'orange', 'enabled': True, 'name': 'CPOE', 'resource_type': 'enum_option'}, {'gid': '1203934098502865', 'color': 'yellow', 'enabled': True, 'name': '院內公告', 'resource_type': 'enum_option'}, {'gid': '1203934098502956', 'color': 'pink', 'enabled': True, 'name': '過敏及不良反應', 'resource_type': 'enum_option'}, {'gid': '1203934098502933', 'color': 'blue', 'enabled': True, 'name': '列印', 'resource_type': 'enum_option'}, {'gid': '1203934098502945', 'color': 'magenta', 'enabled': True, 'name': '問卷', 'resource_type': 'enum_option'}, {'gid': '1203934098502953', 'color': 'hot-pink', 'enabled': True, 'name': '轉診', 'resource_type': 'enum_option'}, {'gid': '1203934098502860', 'color': 'yellow-orange', 'enabled': True, 'name': 'LifeCycle', 'resource_type': 'enum_option'}, {'gid': '1203934098502835', 'color': 'red', 'enabled': True, 'name': '環境設備', 'resource_type': 'enum_option'}, {'gid': '1203934098502965', 'color': 'none', 'enabled': True, 'name': '手術', 'resource_type': 'enum_option'}, {'gid': '1203934098502988', 'color': 'none', 'enabled': True, 'name': '電子表單', 'resource_type': 'enum_option'}, {'gid': '1203934098503005', 'color': 'none', 'enabled': True, 'name': '系統交互', 'resource_type': 'enum_option'}, {'gid': '1203934098503248', 'color': 'none', 'enabled': True, 'name': '電子病歷', 'resource_type': 'enum_option'}, {'gid': '1203934098503013', 'color': 'none', 'enabled ...
# /Users/kuoyihsin/opt/anaconda3/lib/python3.9/site-packages/asana/client.py:156: UserWarning: This request is affected by the "new_goal_memberships" deprecation. Please visit this url for more info: https://forum.asana.com/t/launched-team-sharing-for-goals/378601
# Adding "new_goal_memberships" to your "Asana-Enable" or "Asana-Disable" header will opt in/out to this deprecation and suppress this warning.
#   warnings.warn(message)

# %%
print(result['custom_fields'])
# Out:
# [{'gid': '1202515689429806', 'enabled': True, 'name': 'ID', 'description': '', 'created_by': {'gid': '1146190415685286', 'name': 'Jackie Yang', 'resource_type': 'user'}, 'display_value': None, 'resource_subtype': 'text', 'resource_type': 'custom_field', 'text_value': None, 'type': 'text'}, {'gid': '977653033713577', 'enabled': True, 'enum_options': [{'gid': '977653033713578', 'color': 'red', 'enabled': True, 'name': 'High', 'resource_type': 'enum_option'}, {'gid': '977653033713579', 'color': 'orange', 'enabled': True, 'name': 'Medium', 'resource_type': 'enum_option'}, {'gid': '977653033713580', 'color': 'yellow-orange', 'enabled': True, 'name': 'Low', 'resource_type': 'enum_option'}], 'enum_value': {'gid': '977653033713579', 'color': 'orange', 'enabled': True, 'name': 'Medium', 'resource_type': 'enum_option'}, 'name': 'Priority', 'description': 'Asana-created. Track the priority of each task.', 'created_by': None, 'display_value': 'Medium', 'resource_subtype': 'enum', 'resource_type': 'custom_field', 'type': 'enum'}, {'gid': '1202485156593297', 'enabled': True, 'enum_options': [{'gid': '1202485156593298', 'color': 'green', 'enabled': True, 'name': 'EPIC 1', 'resource_type': 'enum_option'}, {'gid': '1202485156593299', 'color': 'red', 'enabled': True, 'name': 'EPIC 2', 'resource_type': 'enum_option'}, {'gid': '1202485156593300', 'color': 'orange', 'enabled': True, 'name': 'EPIC 3', 'resource_type': 'enum_option'}, {'gid': '1202485156593301', 'color': 'yellow-orange', 'enabled': True, 'name': 'EPIC 4', 'resource_type': 'enum_option'}, {'gid': '1202485156593302', 'color': 'yellow', 'enabled': True, 'name': 'EPIC 5', 'resource_type': 'enum_option'}, {'gid': '1202485156593303', 'color': 'yellow-green', 'enabled': True, 'name': 'EPIC 6', 'resource_type': 'enum_option'}, {'gid': '1202485156593304', 'color': 'blue-green', 'enabled': True, 'name': 'EPIC 7', 'resource_type': 'enum_option'}, {'gid': '1202485156593305', 'color': 'aqua', 'enabled': True, 'name': 'EPIC 8', 'resource_type': 'enum_option'}, {'gid': '1202485156593306', 'color': 'blue', 'enabled': True, 'name': 'EPIC 9', 'resource_type': 'enum_option'}, {'gid': '1202485156593307', 'color': 'indigo', 'enabled': True, 'name': 'EPIC 10', 'resource_type': 'enum_option'}, {'gid': '1202485156593310', 'color': 'purple', 'enabled': True, 'name': 'EPIC 11', 'resource_type': 'enum_option'}], 'enum_value': None, 'name': 'EPIC 8', 'description': '', 'created_by': {'gid': '1146190415685286', 'name': 'Jackie Yang', 'resource_type': 'user'}, 'display_value': None, 'resource_subtype': 'enum', 'resource_type': 'custom_field', 'type': 'enum'}, {'gid': '1198840417939478', 'enabled': True, 'enum_options': [{'gid': '1198840417939484', 'color': 'indigo', 'enabled': True, 'name': 'M2', 'resource_type': 'enum_option'}, {'gid': '1201610697173537', 'color': 'aqua', 'enabled': True, 'name': 'M3', 'resource_type': 'enum_option'}, {'gid': '1198840417939487', 'color': 'red', 'enabled': True, 'name': 'M4', 'resource_type': 'enum_option'}, {'gid': '1198840417939489', 'color': 'orange', 'enabled': True, 'name': 'M5', 'resource_type': 'enum_option'}, {'gid': '1198840417939491', 'color': 'yellow-orange', 'enabled': True, 'name': 'M6', 'resource_type': 'enum_option'}, {'gid': '1201991502979214', 'color': 'yellow', 'enabled': True, 'name': 'Backlog', 'resource_type': 'enum_option'}, {'gid': '1202343832063475', 'color': 'yellow-green', 'enabled': True, 'name': 'M4-redo', 'resource_type': 'enum_option'}, {'gid': '1202545097656525', 'color': 'blue-green', 'enabled': True, 'name': 'Sprint3', 'resource_type': 'enum_option'}, {'gid': '1202579552727468', 'color': 'green', 'enabled': True, 'name': 'Sprint4', 'resource_type': 'enum_option'}, {'gid': '1202686494641660', 'color': 'blue', 'enabled': True, 'name': 'Sprint5', 'resource_type': 'enum_option'}, {'gid': '1202695536930024', 'color': 'purple', 'enabled': True, 'name': 'Sprint6', 'resource_type': 'enum_option'}, {'gid': '1202782000679362', 'color': 'magenta', 'enabled' ...

# %%
result
# Out:
# {'gid': '1203751583595248',
#  'custom_fields': [{'gid': '1202515689429806',
#    'enabled': True,
#    'name': 'ID',
#    'description': '',
#    'created_by': {'gid': '1146190415685286',
#     'name': 'Jackie Yang',
#     'resource_type': 'user'},
#    'display_value': None,
#    'resource_subtype': 'text',
#    'resource_type': 'custom_field',
#    'text_value': None,
#    'type': 'text'},
#   {'gid': '977653033713577',
#    'enabled': True,
#    'enum_options': [{'gid': '977653033713578',
#      'color': 'red',
#      'enabled': True,
#      'name': 'High',
#      'resource_type': 'enum_option'},
#     {'gid': '977653033713579',
#      'color': 'orange',
#      'enabled': True,
#      'name': 'Medium',
#      'resource_type': 'enum_option'},
#     {'gid': '977653033713580',
#      'color': 'yellow-orange',
#      'enabled': True,
#      'name': 'Low',
#      'resource_type': 'enum_option'}],
#    'enum_value': {'gid': '977653033713579',
#     'color': 'orange',
#     'enabled': True,
#     'name': 'Medium',
#     'resource_type': 'enum_option'},
#    'name': 'Priority',
#    'description': 'Asana-created. Track the priority of each task.',
#    'created_by': None,
#    'display_value': 'Medium',
#    'resource_subtype': 'enum',
#    'resource_type': 'custom_field',
#    'type': 'enum'},
#   {'gid': '1202485156593297',
#    'enabled': True,
#    'enum_options': [{'gid': '1202485156593298',
#      'color': 'green',
#      'enabled': True,
#      'name': 'EPIC 1',
#      'resource_type': 'enum_option'},
#     {'gid': '1202485156593299',
#      'color': 'red',
#      'enabled': True,
#      'name': 'EPIC 2',
#      'resource_type': 'enum_option'},
#     {'gid': '1202485156593300',
#      'color': 'orange',
#      'enabled': True,
#      'name': 'EPIC 3',
#      'resource_type': 'enum_option'},
#     {'gid': '1202485156593301',
#      'color': 'yellow-orange',
#      'enabled': True,
#      'name': 'EPIC 4',
#      'resource_type': 'enum_option'},
#     {'gid': '1202485156593302',
#      'color': 'yellow',
#      'enabled': True,
#      'name': 'EPIC 5',
#      'resource_type': 'enum_option'},
#     {'gid': '1202485156593303',
#      'color': 'yellow-green',
#      'enabled': True,
#      'name': 'EPIC 6',
#      'resource_type': 'enum_option'},
#     {'gid': '1202485156593304',
#      'color': 'blue-green',
#      'enabled': True,
#      'name': 'EPIC 7',
#      'resource_type': 'enum_option'},
#     {'gid': '1202485156593305',
#      'color': 'aqua',
#      'enabled': True,
#      'name': 'EPIC 8',
#      'resource_type': 'enum_option'},
#     {'gid': '1202485156593306',
#      'color': 'blue',
#      'enabled': True,
#      'name': 'EPIC 9',
#      'resource_type': 'enum_option'},
#     {'gid': '1202485156593307',
#      'color': 'indigo',
#      'enabled': True,
#      'name': 'EPIC 10',
#      'resource_type': 'enum_option'},
#     {'gid': '1202485156593310',
#      'color': 'purple',
#      'enabled': True,
#      'name': 'EPIC 11',
#      'resource_type': 'enum_option'}],
#    'enum_value': None,
#    'name': 'EPIC 8',
#    'description': '',
#    'created_by': {'gid': '1146190415685286',
#     'name': 'Jackie Yang',
#     'resource_type': 'user'},
#    'display_value': None,
#    'resource_subtype': 'enum',
#    'resource_type': 'custom_field',
#    'type': 'enum'},
#   {'gid': '1198840417939478',
#    'enabled': True,
#    'enum_options': [{'gid': '1198840417939484',
#      'color': 'indigo',
#      'enabled': True,
#      'name': 'M2',
#      'resource_type': 'enum_option'},
#     {'gid': '1201610697173537',
#      'color': 'aqua',
#      'enabled': True,
#      'name': 'M3',
#      'resource_type': 'enum_option'},
#     {'gid': '1198840417939487',
#      'color': 'red',
#      'enabled': True,
#      'name': 'M4',
#      'resource_type': 'enum_option'},
#     {'gid': '1198840417939489',
#      'color': 'orange',
#      'enabled': True,
#      'name': 'M5',
#      'resource_type': 'enum_option'},
#     {'gid': '1198840417939491',
#      'color': 'yellow-orange',
#      'enabled': True,
#      'name': 'M6',
#      'resource_type': 'enum_option'},
#     {'gid': '1201991502979214',
#      'color': 'yellow',
#      'enabled': True,
#      'name': 'Backlog',
#      'resource_type': 'enum_option'},
#     {'gid': '1202343832063475',
#      'color': 'yellow-green',
#      'enabled': True,
#      'name': 'M4-redo',
#      'resource_type': 'enum_option'},
#     {'gid': '1202545097656525',
#      'color': 'blue-green',
#      'enabled': True,
#      'name': 'Sprint3',
#      'resource_type': 'enum_option'},
#     {'gid': '1202579552727468',
#      'color': 'green',
#      'enabled': True,
#      'name': 'Sprint4',
#      'resource_type': 'enum_option'},
#     {'gid': '1202686494641660',
#      'color': 'blue',
#      'enabled': True,
#      'name': 'Sprint5',
#      'resource_type': 'enum_option'},
#     {'gid': '1202695536930024',
#      'color': 'purple',
#      'enabled': True,
#      'name': 'Sprint6',
#      'resource_type': 'enum_option'},
#     {'gid': '1202782000679362',
#      'color': 'magenta',
#      'enabled': True,
#      'name': 'Sprint7',
#      'resource_type': 'enum_option'},
#     {'gid': '1203002374132139',
#      'color': 'hot-pink',
#      'enabled': True,
#      'name': 'Sprint2',
#      'resource_type': 'enum_option'},
#     {'gid': '1202827777089208',
#      'color': 'pink',
#      'enabled': True,
#      'name': 'PI-1',
#      'resource_type': 'enum_option'},
#     {'gid': '1202905067109252',
#      'color': 'cool-gray',
#      'enabled': True,
#      'name': 'PI-2',
#      'resource_type': 'enum_option'},
#     {'gid': '1203240917364679',
#      'color': 'aqua',
#      'enabled': True,
#      'name': 'PI-3',
#      'resource_type': 'enum_option'},
#     {'gid': '1203751271828891',
#      'color': 'indigo',
#      'enabled': True,
#      'name': 'PI-4',
#      'resource_type': 'enum_option'},
#     {'gid': '1204111277076562',
#      'color': 'none',
#      'enabled': True,
#      'name': 'PI-5',
#      'resource_type': 'enum_option'}],
#    'enum_value': None,
#    'name': 'Milestone',
#    'description': '',
#    'created_by': {'gid': '1153162174946043',
#     'name': 'Ted Huang',
#     'resource_type': 'user'},
#    'display_value': None,
#    'resource_subtype': 'enum',
#    'resource_type': 'custom_field',
#    'type': 'enum'},
#   {'gid': '1201889484339892',
#    'enabled': True,
#    'enum_options': [{'gid': '1201889424753977',
#      'color': 'yellow-green',
#      'enabled': True,
#      'name': 'User Story',
#      'resource_type': 'enum_option'},
#     {'gid': '1201889484339893',
#      'color': 'green',
#      'enabled': True,
#      'name': 'Function (PM)',
#      'resource_type': 'enum_option'},
#     {'gid': '1201889484340027',
#      'color': 'orange',
#      'enabled': True,
#      'name': 'Feature Request',
#      'resource_type': 'enum_option'},
#     {'gid': '1201889484340029',
#      'color': 'yellow-orange',
#      'enabled': True,
#      'name': 'Change Request',
#      'resource_type': 'enum_option'},
#     {'gid': '1201889484340023',
#      'color': 'red',
#      'enabled': True,
#      'name': 'Defect',
#      'resource_type': 'enum_option'},
#     {'gid': '1201889484340094',
#      'color': 'yellow',
#      'enabled': True,
#      'name': 'Known Issue',
#      'resource_type': 'enum_option'},
#     {'gid': '1202251662425063',
#      'color': 'magenta',
#      'enabled': True,
#      'name': 'Enhancement',
#      'resource_type': 'enum_option'},
#     {'gid': '1201891684908750',
#      'color': 'blue-green',
#      'enabled': True,
#      'name': 'Risk',
#      'resource_type': 'enum_option'},
#     {'gid': '1201891590706255',
#      'color': 'aqua',
#      'enabled': True,
#      'name': 'Milestone',
#      'resource_type': 'enum_option'},
#     {'gid': '1202182378562150',
#      'color': 'blue',
#      'enabled': True,
#      'name': 'By Design',
#      'resource_type': 'enum_option'},
#     {'gid': '1202182383465040',
#      'color': 'indigo',
#      'enabled': True,
#      'name': 'Duplicated',
#      'resource_type': 'enum_option'},
#     {'gid': '1202182390157780',
#      'color': 'purple',
#      'enabled': True,
#      'name': 'Not a Defect',
#      'resource_type': 'enum_option'},
#     {'gid': '1203512867189580',
#      'color': 'hot-pink',
#      'enabled': True,
#      'name': 'KIV',
#      'resource_type': 'enum_option'},
#     {'gid': '1204236893653736',
#      'color': 'pink',
#      'enabled': True,
#      'name': 'Reject',
#      'resource_type': 'enum_option'}],
#    'enum_value': {'gid': '1201889484340023',
#     'color': 'red',
#     'enabled': True,
#     'name': 'Defect',
#     'resource_type': 'enum_option'},
#    'name': 'Type',
#    'description': '',
#    'created_by': {'gid': '1153162174946043',
#     'name': 'Ted Huang',
#     'resource_type': 'user'},
#    'display_value': 'Defect',
#    'resource_subtype': 'enum',
#    'resource_type': 'custom_field',
#    'type': 'enum'},
#   {'gid': '1204151393723065',
#    'enabled': True,
#    'enum_options': [{'gid': '1204191076977825',
#      'color': 'red',
#      'enabled': True,
#      'name': 'v.next Hotfix',
#      'resource_type': 'enum_option'},
#     {'gid': '1204191215556915',
#      'color': 'red',
#      'enabled': True,
#      'name': 'v.next Feature',
#      'resource_type': 'enum_option'},
#     {'gid': '1204370943928676',
#      'color': 'none',
#      'enabled': True,
#      'name': 'XRT0011W',
#      'resource_type': 'enum_option'},
#     {'gid': '1204370943928675',
#      'color': 'none',
#      'enabled': True,
#      'name': 'XRT0010H',
#      'resource_type': 'enum_option'},
#     {'gid': '1204256012972448',
#      'color': 'none',
#      'enabled': True,
#      'name': 'XRT0009W',
#      'resource_type': 'enum_option'},
#     {'gid': '1204213162513273',
#      'color': 'none',
#      'enabled': True,
#      'name': 'XRT0008H',
#      'resource_type': 'enum_option'},
#     {'gid': '1204151393723066',
#      'color': 'none',
#      'enabled': True,
#      'name': 'XRT0007W',
#      'resource_type': 'enum_option'},
#     {'gid': '1204151393723067',
#      'color': 'none',
#      'enabled': True,
#      'name': 'XRT0006H',
#      'resource_type': 'enum_option'},
#     {'gid': '1204190912755613',
#      'color': 'none',
#      'enabled': True,
#      'name': 'XRT0005H',
#      'resource_type': 'enum_option'},
#     {'gid': '1204190396223455',
#      'color': 'none',
#      'enabled': True,
#      'name': 'XRT0004W',
#      'resource_type': 'enum_option'}],
#    'multi_enum_values': [],
#    'name': 'xRelease',
#    'description': '',
#    'created_by': {'gid': '1146187112437384',
#     'name': 'Robert Lu',
#     'resource_type': 'user'},
#    'display_value': None,
#    'resource_subtype': 'multi_enum',
#    'resource_type': 'custom_field',
#    'type': 'multi_enum'},
#   {'gid': '1204231431532899',
#    'enabled': True,
#    'name': 'Overview',
#    'description': 'Task overview ',
#    'created_by': {'gid': '1203139226376547',
#     'name': 'Luke Hou',
#     'resource_type': 'user'},
#    'display_value': None,
#    'resource_subtype': 'text',
#    'resource_type': 'custom_field',
#    'text_value': None,
#    'type': 'text'},
#   {'gid': '1204235051512095',
#    'enabled': True,
#    'name': 'IT Collaborator',
#    'description': '',
#    'created_by': {'gid': '1203139226376547',
#     'name': 'Luke Hou',
#     'resource_type': 'user'},
#    'display_value': None,
#    'resource_subtype': 'text',
#    'resource_type': 'custom_field',
#    'text_value': None,
#    'type': 'text'},
#   {'gid': '1199146785128829',
#    'enabled': True,
#    'enum_options': [{'gid': '1199146785128830',
#      'color': 'green',
#      'enabled': True,
#      'name': 'AICS',
#      'resource_type': 'enum_option'},
#     {'gid': '1199146785128831',
#      'color': 'red',
#      'enabled': True,
#      'name': 'Unimax',
#      'resource_type': 'enum_option'},
#     {'gid': '1199146785128832',
#      'color': 'orange',
#      'enabled': True,
#      'name': 'CC',
#      'resource_type': 'enum_option'},
#     {'gid': '1202469683047452',
#      'color': 'yellow-orange',
#      'enabled': True,
#      'name': 'Widget',
#      'resource_type': 'enum_option'}],
#    'enum_value': None,
#    'name': 'Integration',
#    'description': '',
#    'created_by': {'gid': '1153162174946043',
#     'name': 'Ted Huang',
#     'resource_type': 'user'},
#    'display_value': None,
#    'resource_subtype': 'enum',
#    'resource_type': 'custom_field',
#    'type': 'enum'},
#   {'gid': '1112312177817784',
#    'enabled': True,
#    'enum_options': [{'gid': '1112312177817785',
#      'color': 'blue',
#      'enabled': True,
#      'name': 'Not Started',
#      'resource_type': 'enum_option'},
#     {'gid': '1112312177817786',
#      'color': 'cool-gray',
#      'enabled': True,
#      'name': 'In Progress',
#      'resource_type': 'enum_option'},
#     {'gid': '1112312177817787',
#      'color': 'yellow',
#      'enabled': True,
#      'name': 'Waiting',
#      'resource_type': 'enum_option'},
#     {'gid': '1112312177817788',
#      'color': 'orange',
#      'enabled': True,
#      'name': 'Deferred',
#      'resource_type': 'enum_option'},
#     {'gid': '1112312177817789',
#      'color': 'blue-green',
#      'enabled': True,
#      'name': 'Done',
#      'resource_type': 'enum_option'}],
#    'enum_value': {'gid': '1112312177817789',
#     'color': 'blue-green',
#     'enabled': True,
#     'name': 'Done',
#     'resource_type': 'enum_option'},
#    'name': 'Task Progress',
#    'description': 'Asana-created. Track the progress of each task.',
#    'created_by': None,
#    'display_value': 'Done',
#    'resource_subtype': 'enum',
#    'resource_type': 'custom_field',
#    'type': 'enum'},
#   {'gid': '1202545417468396',
#    'enabled': True,
#    'enum_options': [{'gid': '1202545417468397',
#      'color': 'green',
#      'enabled': True,
#      'name': 'PM spec',
#      'resource_type': 'enum_option'},
#     {'gid': '1202545417468398',
#      'color': 'red',
#      'enabled': True,
#      'name': 'DaaS data',
#      'resource_type': 'enum_option'},
#     {'gid': '1202545417468399',
#      'color': 'orange',
#      'enabled': True,
#      'name': 'UX design',
#      'resource_type': 'enum_option'},
#     {'gid': '1202545417468400',
#      'color': 'yellow-orange',
#      'enabled': True,
#      'name': 'Tool operator',
#      'resource_type': 'enum_option'},
#     {'gid': '1202545417468401',
#      'color': 'yellow',
#      'enabled': True,
#      'name': 'Tool path',
#      'resource_type': 'enum_option'},
#     {'gid': '1202550745969357',
#      'color': 'yellow-green',
#      'enabled': True,
#      'name': 'PM config',
#      'resource_type': 'enum_option'}],
#    'multi_enum_values': [],
#    'name': 'Regulation Pending Reason',
#    'description': '',
#    'created_by': {'gid': '1201275664065412',
#     'name': 'Johnny Lai',
#     'resource_type': 'user'},
#    'display_value': None,
#    'resource_subtype': 'multi_enum',
#    'resource_type': 'custom_field',
#    'type': 'multi_enum'},
#   {'gid': '1202047054279830',
#    'enabled': True,
#    'enum_options': [{'gid': '1202047054279831',
#      'color': 'green',
#      'enabled': True,
#      'name': 'Show Stopper',
#      'resource_type': 'enum_option'},
#     {'gid': '1202047054279832',
#      'color': 'red',
#      'enabled': True,
#      'name': 'Obvious Defect',
#      'resource_type': 'enum_option'},
#     {'gid': '1202047054279833',
#      'color': 'orange',
#      'enabled': True,
#      'name': 'Re-opened',
#      'resource_type': 'enum_option'},
#     {'gid': '1202047054279834',
#      'color': 'yellow',
#      'enabled': True,
#      'name': 'Integration Defect',
#      'resource_type': 'enum_option'},
#     {'gid': '1202047054279835',
#      'color': 'yellow-orange',
#      'enabled': True,
#      'name': 'By design',
#      'resource_type': 'enum_option'},
#     {'gid': '1202092538540825',
#      'color': 'yellow-green',
#      'enabled': True,
#      'name': 'Random Issue',
#      'resource_type': 'enum_option'},
#     {'gid': '1202092538540831',
#      'color': 'blue-green',
#      'enabled': True,
#      'name': 'Usability',
#      'resource_type': 'enum_option'},
#     {'gid': '1202501729421384',
#      'color': 'aqua',
#      'enabled': True,
#      'name': 'Exception',
#      'resource_type': 'enum_option'}],
#    'enum_value': None,
#    'name': 'Defect Category',
#    'description': '',
#    'created_by': {'gid': '1153162174946043',
#     'name': 'Ted Huang',
#     'resource_type': 'user'},
#    'display_value': None,
#    'resource_subtype': 'enum',
#    'resource_type': 'custom_field',
#    'type': 'enum'},
#   {'gid': '1203645853552870',
#    'enabled': True,
#    'enum_options': [{'gid': '1203645853552871',
#      'color': 'red',
#      'enabled': True,
#      'name': 'DaaS',
#      'resource_type': 'enum_option'},
#     {'gid': '1203645853552872',
#      'color': 'orange',
#      'enabled': True,
#      'name': 'Frontend',
#      'resource_type': 'enum_option'},
#     {'gid': '1203645853552891',
#      'color': 'aqua',
#      'enabled': True,
#      'name': 'Rule',
#      'resource_type': 'enum_option'},
#     {'gid': '1203645853552873',
#      'color': 'yellow-orange',
#      'enabled': True,
#      'name': 'Backend',
#      'resource_type': 'enum_option'},
#     {'gid': '1203645853552874',
#      'color': 'yellow',
#      'enabled': True,
#      'name': 'Native App',
#      'resource_type': 'enum_option'},
#     {'gid': '1203645853552876',
#      'color': 'yellow-green',
#      'enabled': True,
#      'name': 'Reused Module',
#      'resource_type': 'enum_option'},
#     {'gid': '1203645853552881',
#      'color': 'green',
#      'enabled': True,
#      'name': 'IC 2.0',
#      'resource_type': 'enum_option'},
#     {'gid': '1203645853552883',
#      'color': 'blue-green',
#      'enabled': True,
#      'name': 'Not an issue',
#      'resource_type': 'enum_option'}],
#    'enum_value': None,
#    'name': 'Cause',
#    'description': '',
#    'created_by': {'gid': '1153162174946043',
#     'name': 'Ted Huang',
#     'resource_type': 'user'},
#    'display_value': None,
#    'resource_subtype': 'enum',
#    'resource_type': 'custom_field',
#    'type': 'enum'},
#   {'gid': '1202139282571672',
#    'enabled': True,
#    'enum_options': [{'gid': '1202273306960987',
#      'color': 'blue-green',
#      'enabled': True,
#      'name': 'Specification',
#      'resource_type': 'enum_option'},
#     {'gid': '1202139282571682',
#      'color': 'yellow',
#      'enabled': True,
#      'name': 'UX/UI Design',
#      'resource_type': 'enum_option'},
#     {'gid': '1202139282769136',
#      'color': 'yellow-green',
#      'enabled': True,
#      'name': 'Architecture',
#      'resource_type': 'enum_option'},
#     {'gid': '1202139282571673',
#      'color': 'green',
#      'enabled': True,
#      'name': 'Code/Unit Test',
#      'resource_type': 'enum_option'},
#     {'gid': '1202139282571676',
#      'color': 'yellow-orange',
#      'enabled': True,
#      'name': 'Data Availability',
#      'resource_type': 'enum_option'},
#     {'gid': '1202273306960988',
#      'color': 'red',
#      'enabled': True,
#      'name': 'E2E Integration',
#      'resource_type': 'enum_option'},
#     {'gid': '1202273306960989',
#      'color': 'blue',
#      'enabled': True,
#      'name': 'Legacy Integration',
#      'resource_type': 'enum_option'},
#     {'gid': '1204134218217433',
#      'color': 'orange',
#      'enabled': True,
#      'name': 'Data sync',
#      'resource_type': 'enum_option'},
#     {'gid': '1204134218217434',
#      'color': 'aqua',
#      'enabled': True,
#      'name': 'Write back',
#      'resource_type': 'enum_option'},
#     {'gid': '1204134218217435',
#      'color': 'indigo',
#      'enabled': True,
#      'name': 'RS server',
#      'resource_type': 'enum_option'},
#     {'gid': '1204134233433311',
#      'color': 'magenta',
#      'enabled': True,
#      'name': 'Missing spec',
#      'resource_type': 'enum_option'},
#     {'gid': '1204134118121500',
#      'color': 'purple',
#      'enabled': True,
#      'name': "CC's issue",
#      'resource_type': 'enum_option'}],
#    'enum_value': None,
#    'name': 'Defect Injection',
#    'description': '',
#    'created_by': {'gid': '1146187112437384',
#     'name': 'Robert Lu',
#     'resource_type': 'user'},
#    'display_value': None,
#    'resource_subtype': 'enum',
#    'resource_type': 'custom_field',
#    'type': 'enum'},
#   {'gid': '1202007505828890',
#    'enabled': True,
#    'enum_options': [{'gid': '1202007505828891',
#      'color': 'green',
#      'enabled': True,
#      'name': 'High',
#      'resource_type': 'enum_option'},
#     {'gid': '1202007505828892',
#      'color': 'red',
#      'enabled': True,
#      'name': 'Medium',
#      'resource_type': 'enum_option'},
#     {'gid': '1202007505828893',
#      'color': 'orange',
#      'enabled': True,
#      'name': 'Low',
#      'resource_type': 'enum_option'}],
#    'enum_value': None,
#    'name': 'Risk',
#    'description': '',
#    'created_by': {'gid': '1153162174946043',
#     'name': 'Ted Huang',
#     'resource_type': 'user'},
#    'display_value': None,
#    'resource_subtype': 'enum',
#    'resource_type': 'custom_field',
#    'type': 'enum'},
#   {'gid': '1202007505828764',
#    'enabled': True,
#    'enum_options': [{'gid': '1202007505828765',
#      'color': 'green',
#      'enabled': True,
#      'name': 'Confirmed',
#      'resource_type': 'enum_option'},
#     {'gid': '1202007505828766',
#      'color': 'red',
#      'enabled': True,
#      'name': 'Possible',
#      'resource_type': 'enum_option'},
#     {'gid': '1202007505828767',
#      'color': 'orange',
#      'enabled': True,
#      'name': 'Less Likely',
#      'resource_type': 'enum_option'},
#     {'gid': '1202007505828822',
#      'color': 'yellow-orange',
#      'enabled': True,
#      'name': 'N/A',
#      'resource_type': 'enum_option'},
#     {'gid': '1202124239327523',
#      'color': 'yellow',
#      'enabled': True,
#      'name': 'Ready',
#      'resource_type': 'enum_option'}],
#    'enum_value': None,
#    'name': 'DaaS',
#    'description': '',
#    'created_by': {'gid': '1153162174946043',
#     'name': 'Ted Huang',
#     'resource_type': 'user'},
#    'display_value': None,
#    'resource_subtype': 'enum',
#    'resource_type': 'custom_field',
#    'type': 'enum'},
#   {'gid': '1202007505828769',
#    'enabled': True,
#    'enum_options': [{'gid': '1202007505828770',
#      'color': 'green',
#      'enabled': True,
#      'name': 'Confirmed',
#      'resource_type': 'enum_option'},
#     {'gid': '1202007505828771',
#      'color': 'red',
#      'enabled': True,
#      'name': 'Possible',
#      'resource_type': 'enum_option'},
#     {'gid': '1202007505828772',
#      'color': 'orange',
#      'enabled': True,
#      'name': 'Less Likely',
#      'resource_type': 'enum_option'},
#     {'gid': '1202007505828847',
#      'color': 'yellow-orange',
#      'enabled': True,
#      'name': 'N/A',
#      'resource_type': 'enum_option'},
#     {'gid': '1202124239327524',
#      'color': 'yellow',
#      'enabled': True,
#      'name': 'Ready',
#      'resource_type': 'enum_option'}],
#    'enum_value': None,
#    'name': 'State',
#    'description': '',
#    'created_by': {'gid': '1153162174946043',
#     'name': 'Ted Huang',
#     'resource_type': 'user'},
#    'display_value': None,
#    'resource_subtype': 'enum',
#    'resource_type': 'custom_field',
#    'type': 'enum'},
#   {'gid': '1202007505828774',
#    'enabled': True,
#    'enum_options': [{'gid': '1202007505828775',
#      'color': 'green',
#      'enabled': True,
#      'name': 'Confirmed',
#      'resource_type': 'enum_option'},
#     {'gid': '1202007505828776',
#      'color': 'red',
#      'enabled': True,
#      'name': 'Possible',
#      'resource_type': 'enum_option'},
#     {'gid': '1202007505828777',
#      'color': 'orange',
#      'enabled': True,
#      'name': 'Less Likely',
#      'resource_type': 'enum_option'},
#     {'gid': '1202007505828848',
#      'color': 'yellow-orange',
#      'enabled': True,
#      'name': 'N/A',
#      'resource_type': 'enum_option'},
#     {'gid': '1202124239327525',
#      'color': 'yellow',
#      'enabled': True,
#      'name': 'Ready',
#      'resource_type': 'enum_option'}],
#    'enum_value': None,
#    'name': 'Widget',
#    'description': '',
#    'created_by': {'gid': '1153162174946043',
#     'name': 'Ted Huang',
#     'resource_type': 'user'},
#    'display_value': None,
#    'resource_subtype': 'enum',
#    'resource_type': 'custom_field',
#    'type': 'enum'},
#   {'gid': '1202007505828779',
#    'enabled': True,
#    'enum_options': [{'gid': '1202007505828780',
#      'color': 'green',
#      'enabled': True,
#      'name': 'Confirmed',
#      'resource_type': 'enum_option'},
#     {'gid': '1202007505828781',
#      'color': 'red',
#      'enabled': True,
#      'name': 'Possible',
#      'resource_type': 'enum_option'},
#     {'gid': '1202007505828782',
#      'color': 'orange',
#      'enabled': True,
#      'name': 'Less Likely',
#      'resource_type': 'enum_option'},
#     {'gid': '1202007505828849',
#      'color': 'yellow-orange',
#      'enabled': True,
#      'name': 'N/A',
#      'resource_type': 'enum_option'},
#     {'gid': '1202124239327526',
#      'color': 'yellow',
#      'enabled': True,
#      'name': 'Ready',
#      'resource_type': 'enum_option'}],
#    'enum_value': None,
#    'name': 'Framework',
#    'description': '',
#    'created_by': {'gid': '1153162174946043',
#     'name': 'Ted Huang',
#     'resource_type': 'user'},
#    'display_value': None,
#    'resource_subtype': 'enum',
#    'resource_type': 'custom_field',
#    'type': 'enum'},
#   {'gid': '1202410031470408',
#    'enabled': True,
#    'name': 'Duration',
#    'description': 'Job size',
#    'number_value': None,
#    'precision': 0,
#    'created_by': {'gid': '1146190415685286',
#     'name': 'Jackie Yang',
#     'resource_type': 'user'},
#    'display_value': None,
#    'resource_subtype': 'number',
#    'resource_type': 'custom_field',
#    'type': 'number'},
#   {'gid': '1202459789412364',
#    'enabled': True,
#    'enum_options': [{'gid': '1202459789412365',
#      'color': 'green',
#      'enabled': True,
#      'name': 'Yes',
#      'resource_type': 'enum_option'},
#     {'gid': '1202459789412366',
#      'color': 'red',
#      'enabled': True,
#      'name': 'No',
#      'resource_type': 'enum_option'}],
#    'enum_value': None,
#    'name': 'Collab Related',
#    'description': '',
#    'created_by': {'gid': '1203342687544183',
#     'name': 'Simon Song',
#     'resource_type': 'user'},
#    'display_value': None,
#    'resource_subtype': 'enum',
#    'resource_type': 'custom_field',
#    'type': 'enum'},
#   {'gid': '1203933939401429',
#    'enabled': True,
#    'enum_options': [{'gid': '1203933939401430',
#      'color': 'red',
#      'enabled': True,
#      'name': 'Prod',
#      'resource_type': 'enum_option'},
#     {'gid': '1203933939401431',
#      'color': 'yellow',
#      'enabled': True,
#      'name': 'Stage',
#      'resource_type': 'enum_option'},
#     {'gid': '1203933939401432',
#      'color': 'blue-green',
#      'enabled': True,
#      'name': 'Intt',
#      'resource_type': 'enum_option'},
#     {'gid': '1203933939401433',
#      'color': 'green',
#      'enabled': True,
#      'name': 'Dev',
#      'resource_type': 'enum_option'}],
#    'enum_value': {'gid': '1203933939401432',
#     'color': 'blue-green',
#     'enabled': True,
#     'name': 'Intt',
#     'resource_type': 'enum_option'},
#    'name': 'Report from',
#    'description': '',
#    'created_by': {'gid': '1201379937746423',
#     'name': 'Kevin Hsu',
#     'resource_type': 'user'},
#    'display_value': 'Intt',
#    'resource_subtype': 'enum',
#    'resource_type': 'custom_field',
#    'type': 'enum'},
#   {'gid': '1204022056684789',
#    'enabled': True,
#    'name': 'DefectOwner',
#    'description': '',
#    'created_by': {'gid': '1178606959697684',
#     'name': 'YiminYang',
#     'resource_type': 'user'},
#    'display_value': 'ChengDe Lin',
#    'resource_subtype': 'people',
#    'resource_type': 'custom_field',
#    'people_value': [{'gid': '1201617005196907',
#      'name': 'ChengDe Lin',
#      'resource_type': 'user'}],
#    'type': 'people'},
#   {'gid': '1204021315627725',
#    'enabled': True,
#    'enum_options': [{'gid': '1204021315627726',
#      'color': 'green',
#      'enabled': True,
#      'name': 'Fixed',
#      'resource_type': 'enum_option'},
#     {'gid': '1204021315627727',
#      'color': 'yellow',
#      'enabled': True,
#      'name': 'Postponed',
#      'resource_type': 'enum_option'},
#     {'gid': '1204021315627728',
#      'color': 'purple',
#      'enabled': True,
#      'name': 'By Design',
#      'resource_type': 'enum_option'},
#     {'gid': '1204027708535461',
#      'color': 'red',
#      'enabled': True,
#      'name': "Won't Fix",
#      'resource_type': 'enum_option'},
#     {'gid': '1204377924934089',
#      'color': 'cool-gray',
#      'enabled': True,
#      'name': 'No repro',
#      'resource_type': 'enum_option'}],
#    'enum_value': None,
#    'name': 'Resolution',
#    'description': '',
#    'created_by': {'gid': '1146187112437384',
#     'name': 'Robert Lu',
#     'resource_type': 'user'},
#    'display_value': None,
#    'resource_subtype': 'enum',
#    'resource_type': 'custom_field',
#    'type': 'enum'},
#   {'gid': '1204022056684791',
#    'enabled': True,
#    'name': 'DefectResolver',
#    'description': '',
#    'created_by': {'gid': '1178606959697684',
#     'name': 'YiminYang',
#     'resource_type': 'user'},
#    'display_value': 'joe_lai',
#    'resource_subtype': 'people',
#    'resource_type': 'custom_field',
#    'people_value': [{'gid': '1200691044385560',
#      'name': 'joe_lai',
#      'resource_type': 'user'}],
#    'type': 'people'},
#   {'gid': '1204036362646080',
#    'enabled': True,
#    'enum_options': [{'gid': '1204036362646081',
#      'color': 'green',
#      'enabled': True,
#      'name': 'Automated',
#      'resource_type': 'enum_option'},
#     {'gid': '1204124699309640',
#      'color': 'orange',
#      'enabled': True,
#      'name': 'Partially Automated',
#      'resource_type': 'enum_option'},
#     {'gid': '1204115697181473',
#      'color': 'yellow',
#      'enabled': True,
#      'name': 'In Progress',
#      'resource_type': 'enum_option'},
#     {'gid': '1204115697181474',
#      'color': 'red',
#      'enabled': True,
#      'name': 'To Automate',
#      'resource_type': 'enum_option'},
#     {'gid': '1204234906053321',
#      'color': 'hot-pink',
#      'enabled': True,
#      'name': 'Manual',
#      'resource_type': 'enum_option'},
#     {'gid': '1204234733879588',
#      'color': 'blue',
#      'enabled': True,
#      'name': 'TBD',
#      'resource_type': 'enum_option'}],
#    'enum_value': None,
#    'name': 'Automation Status',
#    'description': '',
#    'created_by': {'gid': '1203139226376547',
#     'name': 'Luke Hou',
#     'resource_type': 'user'},
#    'display_value': None,
#    'resource_subtype': 'enum',
#    'resource_type': 'custom_field',
#    'type': 'enum'},
#   {'gid': '1204115697181482',
#    'enabled': True,
#    'name': 'Automation ID',
#    'description': 'Automation Reference (e.g. caseID or caseName)',
#    'created_by': {'gid': '1203966328135185',
#     'name': 'Jiao Zhang',
#     'resource_type': 'user'},
#    'display_value': None,
#    'resource_subtype': 'text',
#    'resource_type': 'custom_field',
#    'text_value': None,
#    'type': 'text'},
#   {'gid': '1204115697181484',
#    'enabled': True,
#    'name': 'Automation Comments',
#    'description': 'E.g. Automation Solutions, Assessments by Automation Team',
#    'created_by': {'gid': '1203966328135185',
#     'name': 'Jiao Zhang',
#     'resource_type': 'user'},
#    'display_value': None,
#    'resource_subtype': 'text',
#    'resource_type': 'custom_field',
#    'text_value': None,
#    'type': 'text'},
#   {'gid': '1204235051512091',
#    'enabled': True,
#    'enum_options': [{'gid': '1204235051512092',
#      'color': 'green',
#      'enabled': True,
#      'name': 'Done',
#      'resource_type': 'enum_option'},
#     {'gid': '1204235053432647',
#      'color': 'cool-gray',
#      'enabled': True,
#      'name': 'Non-MS',
#      'resource_type': 'enum_option'},
#     {'gid': '1204257833316306',
#      'color': 'red',
#      'enabled': True,
#      'name': 'Legacy',
#      'resource_type': 'enum_option'},
#     {'gid': '1204352788992978',
#      'color': 'yellow',
#      'enabled': True,
#      'name': 'AI Generate',
#      'resource_type': 'enum_option'},
#     {'gid': '1204424177314960',
#      'color': 'orange',
#      'enabled': True,
#      'name': 'SE Todo',
#      'resource_type': 'enum_option'}],
#    'enum_value': {'gid': '1204235051512092',
#     'color': 'green',
#     'enabled': True,
#     'name': 'Done',
#     'resource_type': 'enum_option'},
#    'name': 'MasterScript',
#    'description': '',
#    'created_by': {'gid': '1203139226376547',
#     'name': 'Luke Hou',
#     'resource_type': 'user'},
#    'display_value': 'Done',
#    'resource_subtype': 'enum',
#    'resource_type': 'custom_field',
#    'type': 'enum'},
#   {'gid': '1204353655853405',
#    'enabled': True,
#    'enum_options': [{'gid': '1204353655853406',
#      'color': 'red',
#      'enabled': True,
#      'name': 'Critical',
#      'resource_type': 'enum_option'},
#     {'gid': '1204353655853407',
#      'color': 'orange',
#      'enabled': True,
#      'name': 'Major',
#      'resource_type': 'enum_option'},
#     {'gid': '1204353655853408',
#      'color': 'yellow-orange',
#      'enabled': True,
#      'name': 'Minor',
#      'resource_type': 'enum_option'},
#     {'gid': '1204353655853409',
#      'color': 'yellow',
#      'enabled': True,
#      'name': 'Low',
#      'resource_type': 'enum_option'}],
#    'enum_value': None,
#    'name': 'Severity',
#    'description': '',
#    'created_by': {'gid': '1146190415685286',
#     'name': 'Jackie Yang',
#     'resource_type': 'user'},
#    'display_value': None,
#    'resource_subtype': 'enum',
#    'resource_type': 'custom_field',
#    'type': 'enum'},
#   {'gid': '1203351163202519',
#    'enabled': True,
#    'name': 'Est Cost',
#    'description': '',
#    'number_value': None,
#    'precision': 2,
#    'created_by': {'gid': '1146187112437384',
#     'name': 'Robert Lu',
#     'resource_type': 'user'},
#    'display_value': None,
#    'resource_subtype': 'number',
#    'resource_type': 'custom_field',
#    'type': 'number'},
#   {'gid': '1203351163209806',
#    'enabled': True,
#    'name': 'Cost',
#    'description': '',
#    'number_value': None,
#    'precision': 2,
#    'created_by': {'gid': '1146187112437384',
#     'name': 'Robert Lu',
#     'resource_type': 'user'},
#    'display_value': None,
#    'resource_subtype': 'number',
#    'resource_type': 'custom_field',
#    'type': 'number'},
#   {'gid': '1203351163217116',
#    'enabled': True,
#    'enum_options': [{'gid': '1203351163218209',
#      'color': 'red',
#      'enabled': True,
#      'name': 'Bug',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163225458',
#      'color': 'green',
#      'enabled': True,
#      'name': 'Feature',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163223408',
#      'color': 'yellow',
#      'enabled': True,
#      'name': 'Change',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163229651',
#      'color': 'indigo',
#      'enabled': True,
#      'name': 'Enhancement',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163225576',
#      'color': 'magenta',
#      'enabled': True,
#      'name': 'Request',
#      'resource_type': 'enum_option'},
#     {'gid': '1204257202446247',
#      'color': 'blue',
#      'enabled': True,
#      'name': 'Telemetry',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163225432',
#      'color': 'yellow-orange',
#      'enabled': True,
#      'name': 'Dev',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163217124',
#      'color': 'green',
#      'enabled': True,
#      'name': 'Spec',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163220290',
#      'color': 'orange',
#      'enabled': True,
#      'name': 'Design',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163225484',
#      'color': 'yellow-green',
#      'enabled': True,
#      'name': 'Dependency',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163225534',
#      'color': 'aqua',
#      'enabled': True,
#      'name': 'Rule',
#      'resource_type': 'enum_option'},
#     {'gid': '1203872168648588',
#      'color': 'blue-green',
#      'enabled': True,
#      'name': 'Test Data',
#      'resource_type': 'enum_option'}],
#    'enum_value': {'gid': '1203351163218209',
#     'color': 'red',
#     'enabled': True,
#     'name': 'Bug',
#     'resource_type': 'enum_option'},
#    'name': 'Task Type',
#    'description': '',
#    'created_by': {'gid': '1146187112437384',
#     'name': 'Robert Lu',
#     'resource_type': 'user'},
#    'display_value': 'Bug',
#    'resource_subtype': 'enum',
#    'resource_type': 'custom_field',
#    'type': 'enum'},
#   {'gid': '1203351163244394',
#    'enabled': True,
#    'enum_options': [{'gid': '1203351163244405',
#      'color': 'green',
#      'enabled': True,
#      'name': 'Internal Feature Team',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163246484',
#      'color': 'red',
#      'enabled': True,
#      'name': 'Automation',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163248574',
#      'color': 'orange',
#      'enabled': True,
#      'name': 'Customer',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163249629',
#      'color': 'yellow-orange',
#      'enabled': True,
#      'name': 'SE / IPM',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163252778',
#      'color': 'yellow',
#      'enabled': True,
#      'name': 'Telemetry',
#      'resource_type': 'enum_option'}],
#    'enum_value': {'gid': '1203351163249629',
#     'color': 'yellow-orange',
#     'enabled': True,
#     'name': 'SE / IPM',
#     'resource_type': 'enum_option'},
#    'name': 'Source',
#    'description': '',
#    'created_by': {'gid': '1146187112437384',
#     'name': 'Robert Lu',
#     'resource_type': 'user'},
#    'display_value': 'SE / IPM',
#    'resource_subtype': 'enum',
#    'resource_type': 'custom_field',
#    'type': 'enum'},
#   {'gid': '1203351163269583',
#    'enabled': True,
#    'enum_options': [{'gid': '1203351163269598',
#      'color': 'cool-gray',
#      'enabled': True,
#      'name': 'CPOE',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163273742',
#      'color': 'cool-gray',
#      'enabled': True,
#      'name': 'E2E',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163276910',
#      'color': 'cool-gray',
#      'enabled': True,
#      'name': 'Form',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163278984',
#      'color': 'cool-gray',
#      'enabled': True,
#      'name': 'ICD',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163279004',
#      'color': 'cool-gray',
#      'enabled': True,
#      'name': 'Lifecycle',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163282292',
#      'color': 'cool-gray',
#      'enabled': True,
#      'name': 'xUI',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163284424',
#      'color': 'cool-gray',
#      'enabled': True,
#      'name': 'UX',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163282251',
#      'color': 'cool-gray',
#      'enabled': True,
#      'name': 'RWD',
#      'resource_type': 'enum_option'},
#     {'gid': '1203444795438791',
#      'color': 'cool-gray',
#      'enabled': True,
#      'name': '轉院',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163284451',
#      'color': 'cool-gray',
#      'enabled': True,
#      'name': '初診病史',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163285502',
#      'color': 'cool-gray',
#      'enabled': True,
#      'name': '檢驗檢查報告',
#      'resource_type': 'enum_option'},
#     {'gid': '1203443214813865',
#      'color': 'cool-gray',
#      'enabled': True,
#      'name': '跟診模式',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163285529',
#      'color': 'cool-gray',
#      'enabled': True,
#      'name': '歷史病歷',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163286583',
#      'color': 'cool-gray',
#      'enabled': True,
#      'name': '套餐功能',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163286613',
#      'color': 'cool-gray',
#      'enabled': True,
#      'name': '醫囑',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163287791',
#      'color': 'cool-gray',
#      'enabled': True,
#      'name': '藥囑',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163288835',
#      'color': 'cool-gray',
#      'enabled': True,
#      'name': '預約掛號',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163289878',
#      'color': 'cool-gray',
#      'enabled': True,
#      'name': '病患清單',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163289908',
#      'color': 'cool-gray',
#      'enabled': True,
#      'name': '身分設定',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163292979',
#      'color': 'cool-gray',
#      'enabled': True,
#      'name': '完成看診',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163281201',
#      'color': 'cool-gray',
#      'enabled': True,
#      'name': 'Rule',
#      'resource_type': 'enum_option'},
#     {'gid': '1203530243274084',
#      'color': 'cool-gray',
#      'enabled': True,
#      'name': '離線',
#      'resource_type': 'enum_option'}],
#    'multi_enum_values': [],
#    'name': 'Story',
#    'description': '',
#    'created_by': {'gid': '1146187112437384',
#     'name': 'Robert Lu',
#     'resource_type': 'user'},
#    'display_value': None,
#    'resource_subtype': 'multi_enum',
#    'resource_type': 'custom_field',
#    'type': 'multi_enum'},
#   {'gid': '1177782783594474',
#    'enabled': True,
#    'enum_options': [{'gid': '1177782783594475',
#      'color': 'none',
#      'enabled': True,
#      'name': 'Spec needed',
#      'resource_type': 'enum_option'},
#     {'gid': '1177782783594476',
#      'color': 'none',
#      'enabled': True,
#      'name': 'Design ready',
#      'resource_type': 'enum_option'},
#     {'gid': '1177782783594477',
#      'color': 'none',
#      'enabled': True,
#      'name': 'Eng ready',
#      'resource_type': 'enum_option'},
#     {'gid': '1177782783594478',
#      'color': 'none',
#      'enabled': True,
#      'name': 'QA ready',
#      'resource_type': 'enum_option'},
#     {'gid': '1177782783594479',
#      'color': 'none',
#      'enabled': True,
#      'name': 'Marketing ready',
#      'resource_type': 'enum_option'}],
#    'enum_value': None,
#    'name': 'Product stage',
#    'description': 'Asana-created. Determine the current status of this feature.',
#    'created_by': None,
#    'display_value': None,
#    'resource_subtype': 'enum',
#    'resource_type': 'custom_field',
#    'type': 'enum'},
#   {'gid': '1203351163329507',
#    'enabled': True,
#    'enum_options': [{'gid': '1203351163330557',
#      'color': 'green',
#      'enabled': True,
#      'name': 'Closed',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163331609',
#      'color': 'red',
#      'enabled': True,
#      'name': 'Open',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163334717',
#      'color': 'orange',
#      'enabled': True,
#      'name': 'In Progress',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163335836',
#      'color': 'yellow-orange',
#      'enabled': True,
#      'name': 'Fixed',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163340066',
#      'color': 'yellow',
#      'enabled': True,
#      'name': 'Postponed',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163341113',
#      'color': 'yellow-green',
#      'enabled': True,
#      'name': 'By Design',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163342111',
#      'color': 'blue-green',
#      'enabled': True,
#      'name': 'Duplicate',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163349561',
#      'color': 'aqua',
#      'enabled': True,
#      'name': 'No repro',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163350650',
#      'color': 'blue',
#      'enabled': True,
#      'name': 'Regression',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163350671',
#      'color': 'indigo',
#      'enabled': True,
#      'name': 'Test Issue',
#      'resource_type': 'enum_option'}],
#    'enum_value': None,
#    'name': 'Status',
#    'description': '',
#    'created_by': {'gid': '1146187112437384',
#     'name': 'Robert Lu',
#     'resource_type': 'user'},
#    'display_value': None,
#    'resource_subtype': 'enum',
#    'resource_type': 'custom_field',
#    'type': 'enum'},
#   {'gid': '1203351163358581',
#    'enabled': True,
#    'enum_options': [{'gid': '1203351163359553',
#      'color': 'green',
#      'enabled': True,
#      'name': 'Standard',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163361643',
#      'color': 'red',
#      'enabled': True,
#      'name': 'Normal',
#      'resource_type': 'enum_option'},
#     {'gid': '1203351163362697',
#      'color': 'orange',
#      'enabled': True,
#      'name': 'Emergency',
#      'resource_type': 'enum_option'}],
#    'enum_value': None,
#    'name': 'Change Type',
#    'description': '',
#    'created_by': {'gid': '1146187112437384',
#     'name': 'Robert Lu',
#     'resource_type': 'user'},
#    'display_value': None,
#    'resource_subtype': 'enum',
#    'resource_type': 'custom_field',
#    'type': 'enum'},
#   {'gid': '1203003598091371',
#    'enabled': False,
#    'enum_options': [{'gid': '1203003598091372',
#      'color': 'green',
#      'enabled': True,
#      'name': 'AICS',
#      'resource_type': 'enum_option'},
#     {'gid': '1203003598091373',
#      'color': 'yellow',
#      'enabled': True,
#      'name': 'EIDDC',
#      'resource_type': 'enum_option'},
#     {'gid': '1203952691448473',
#      'color': 'blue',
#      'enabled': True,
#      'name': 'AICS (not rule)',
#      'resource_type': 'enum_option'}],
#    'enum_value': {'gid': '1203003598091372',
#     'color': 'green',
#     'enabled': True,
#     'name': 'AICS',
#     'resource_type': 'enum_option'},
#    'name': 'Owner',
#    'description': '',
#    'created_by': {'gid': '105647033225961',
#     'name': 'Sowhat',
#     'resource_type': 'user'},
#    'display_value': 'AICS',
#    'resource_subtype': 'enum',
#    'resource_type': 'custom_field',
#    'type': 'enum'}],
#  'name': '[Memo] 個人Memo功能異常，會被清空且無法再次正常存入',
#  'notes': '環境：CC Intt\n醫師：6860\n日期：01/17\n病人：B904103\n\n    輸入個人memo\n    回到病患清單，此次在重新進入後個人memo還在\n    點選存回舊系統/完成看診\n    再重新進入該病人，個人memo文字消失，且功能異常(例如點到全院memo再點回個人memo又被清空)\n    至此該病人無法再正常使用個人memo功能\n\n{"userId":"6860","encounterId":"f734a80d-9fbd-5ab5-a718-205fbcabdcd0","doctorId":"6860","operationId":"99664221-20ef-49d6-bebb-6bcd2a685ed7","time":"2023-01-17T10:24:32.331Z","version":{"@asus-aics/aicsapi-frontend-server":"2.0.10","@asus-aics/x-fe-basic":"1.0.14","@asus-aics/x-fe-emitter":"1.0.14","@asus-aics/x-fe-engine":"1.0.153","@asus-aics/x-fe-external":"1.0.2063","@asus-aics/x-fe-logger":"1.0.43","@asus-aics/x-fe-native":"1.0.104","@asus-aics/x-fe-store":"1.0.1","@asus-aics/x-fe-utils":"1.0.107","@asus-aics/xhis-widget-framework":"1.0.52","@asus-aics/xui":"1.4.200"}}\n\n\n'}

# %%
needFields = [  "CaseSuite",
        "Manual Test Coverage",
        "Case Source",
        "Generated By",
        "MainTicket",
        "Manual Test Environment",
        "Pre-Condition",
        "Test Step",
        "Expected Result",
        "xRelease",
        "Manual Test Priority"]

# %%
print(result['data'][0])
# Out:
# {'gid': '1203880492084954', 'custom_field': {'gid': '1203880492084953', 'name': 'Effort', 'precision': 0, 'resource_subtype': 'number', 'resource_type': 'custom_field', 'type': 'number'}, 'is_important': True, 'parent': {'gid': '1203880491753826', 'name': 'MasterScript', 'resource_type': 'project'}, 'project': {'gid': '1203880491753826', 'name': 'MasterScript', 'resource_type': 'project'}, 'resource_type': 'custom_field_setting'}

# %%
result['custom_fields']
# Out:
# [{'gid': '1203880492084953',
#   'enabled': True,
#   'name': 'Effort',
#   'description': '分鐘數',
#   'number_value': 5,
#   'precision': 0,
#   'created_by': {'gid': '1203139226376547',
#    'name': 'Luke Hou',
#    'resource_type': 'user'},
#   'display_value': '5',
#   'resource_subtype': 'number',
#   'resource_type': 'custom_field',
#   'type': 'number'},
#  {'gid': '1203934098502833',
#   'enabled': True,
#   'enum_options': [{'gid': '1204387003439606',
#     'color': 'hot-pink',
#     'enabled': True,
#     'name': '即檢及列印',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098502916',
#     'color': 'blue-green',
#     'enabled': True,
#     'name': '身分設定',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098502998',
#     'color': 'yellow',
#     'enabled': True,
#     'name': 'SOAP',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098503008',
#     'color': 'green',
#     'enabled': True,
#     'name': '下診斷ICD',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098503062',
#     'color': 'pink',
#     'enabled': True,
#     'name': '藥囑',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098502921',
#     'color': 'orange',
#     'enabled': True,
#     'name': '醫囑',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098502962',
#     'color': 'cool-gray',
#     'enabled': True,
#     'name': '歷史病歷',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098503027',
#     'color': 'hot-pink',
#     'enabled': True,
#     'name': '稽核Rule',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098502976',
#     'color': 'none',
#     'enabled': True,
#     'name': '報告查詢',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098502991',
#     'color': 'none',
#     'enabled': True,
#     'name': '套餐(醫療)',
#     'resource_type': 'enum_option'},
#    {'gid': '1204466983046954',
#     'color': 'none',
#     'enabled': True,
#     'name': '就診明細',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098502834',
#     'color': 'green',
#     'enabled': True,
#     'name': '完成看診',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098502941',
#     'color': 'purple',
#     'enabled': True,
#     'name': '身體數據',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098502936',
#     'color': 'indigo',
#     'enabled': True,
#     'name': '健保雲端',
#     'resource_type': 'enum_option'},
#    {'gid': '1204278087004936',
#     'color': 'aqua',
#     'enabled': True,
#     'name': '暫存及存回舊系統',
#     'resource_type': 'enum_option'},
#    {'gid': '1204278011832310',
#     'color': 'yellow-orange',
#     'enabled': True,
#     'name': '清空看診資料(病歷維護)',
#     'resource_type': 'enum_option'},
#    {'gid': '1204124924017144',
#     'color': 'none',
#     'enabled': True,
#     'name': '健保卡及醫事卡',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098502908',
#     'color': 'yellow-green',
#     'enabled': True,
#     'name': '病患清單',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098502854',
#     'color': 'orange',
#     'enabled': True,
#     'name': 'Login',
#     'resource_type': 'enum_option'},
#    {'gid': '1204150600824431',
#     'color': 'orange',
#     'enabled': True,
#     'name': 'CPOE',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098502865',
#     'color': 'yellow',
#     'enabled': True,
#     'name': '院內公告',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098502956',
#     'color': 'pink',
#     'enabled': True,
#     'name': '過敏及不良反應',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098502933',
#     'color': 'blue',
#     'enabled': True,
#     'name': '列印',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098502945',
#     'color': 'magenta',
#     'enabled': True,
#     'name': '問卷',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098502953',
#     'color': 'hot-pink',
#     'enabled': True,
#     'name': '轉診',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098502860',
#     'color': 'yellow-orange',
#     'enabled': True,
#     'name': 'LifeCycle',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098502835',
#     'color': 'red',
#     'enabled': True,
#     'name': '環境設備',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098502965',
#     'color': 'none',
#     'enabled': True,
#     'name': '手術',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098502988',
#     'color': 'none',
#     'enabled': True,
#     'name': '電子表單',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098503005',
#     'color': 'none',
#     'enabled': True,
#     'name': '系統交互',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098503248',
#     'color': 'none',
#     'enabled': True,
#     'name': '電子病歷',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098503013',
#     'color': 'none',
#     'enabled': True,
#     'name': '疫苗',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098503070',
#     'color': 'none',
#     'enabled': True,
#     'name': '偕同編輯',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098503072',
#     'color': 'none',
#     'enabled': True,
#     'name': '掛號',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098503076',
#     'color': 'none',
#     'enabled': True,
#     'name': 'DataSyc',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098503081',
#     'color': 'none',
#     'enabled': True,
#     'name': '再次完成看診',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098503238',
#     'color': 'none',
#     'enabled': True,
#     'name': '癌症相關',
#     'resource_type': 'enum_option'},
#    {'gid': '1203943007360272',
#     'color': 'none',
#     'enabled': True,
#     'name': '災難復原測試',
#     'resource_type': 'enum_option'},
#    {'gid': '1203964893026037',
#     'color': 'none',
#     'enabled': True,
#     'name': '架構及技術',
#     'resource_type': 'enum_option'},
#    {'gid': '1204161832030784',
#     'color': 'none',
#     'enabled': True,
#     'name': '個案管理',
#     'resource_type': 'enum_option'},
#    {'gid': '1204172009992256',
#     'color': 'none',
#     'enabled': True,
#     'name': '批價帳務',
#     'resource_type': 'enum_option'},
#    {'gid': '1204172009992257',
#     'color': 'none',
#     'enabled': True,
#     'name': '保險申報',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098503078',
#     'color': 'none',
#     'enabled': True,
#     'name': '其他',
#     'resource_type': 'enum_option'},
#    {'gid': '1204437681145655',
#     'color': 'none',
#     'enabled': True,
#     'name': 'UI',
#     'resource_type': 'enum_option'}],
#   'multi_enum_values': [{'gid': '1203934098502921',
#     'color': 'orange',
#     'enabled': True,
#     'name': '醫囑',
#     'resource_type': 'enum_option'},
#    {'gid': '1204150600824431',
#     'color': 'orange',
#     'enabled': True,
#     'name': 'CPOE',
#     'resource_type': 'enum_option'}],
#   'name': 'CaseSuite',
#   'description': '',
#   'created_by': {'gid': '1203139226376547',
#    'name': 'Luke Hou',
#    'resource_type': 'user'},
#   'display_value': '醫囑, CPOE',
#   'resource_subtype': 'multi_enum',
#   'resource_type': 'custom_field',
#   'type': 'multi_enum'},
#  {'gid': '1203934098501463',
#   'enabled': True,
#   'enum_options': [{'gid': '1203934098501464',
#     'color': 'red',
#     'enabled': True,
#     'name': 'Smoke',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098501465',
#     'color': 'green',
#     'enabled': True,
#     'name': 'Quick',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098501466',
#     'color': 'indigo',
#     'enabled': True,
#     'name': 'Partial',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098501467',
#     'color': 'yellow-orange',
#     'enabled': True,
#     'name': 'Full',
#     'resource_type': 'enum_option'},
#    {'gid': '1203943007360270',
#     'color': 'orange',
#     'enabled': True,
#     'name': 'Offline',
#     'resource_type': 'enum_option'}],
#   'multi_enum_values': [{'gid': '1203934098501465',
#     'color': 'green',
#     'enabled': True,
#     'name': 'Quick',
#     'resource_type': 'enum_option'}],
#   'name': 'Manual Test Coverage',
#   'description': '',
#   'created_by': {'gid': '1203139226376547',
#    'name': 'Luke Hou',
#    'resource_type': 'user'},
#   'display_value': 'Quick',
#   'resource_subtype': 'multi_enum',
#   'resource_type': 'custom_field',
#   'type': 'multi_enum'},
#  {'gid': '1204395740629735',
#   'enabled': True,
#   'enum_options': [{'gid': '1204395740629736',
#     'color': 'red',
#     'enabled': True,
#     'name': 'High',
#     'resource_type': 'enum_option'},
#    {'gid': '1204395740629737',
#     'color': 'orange',
#     'enabled': True,
#     'name': 'Medium',
#     'resource_type': 'enum_option'},
#    {'gid': '1204395740629738',
#     'color': 'yellow-orange',
#     'enabled': True,
#     'name': 'Low',
#     'resource_type': 'enum_option'}],
#   'enum_value': None,
#   'name': 'Manual Test Priority',
#   'description': 'Asana-created. Track the priority of each task.',
#   'created_by': {'gid': '1203139226376547',
#    'name': 'Luke Hou',
#    'resource_type': 'user'},
#   'display_value': None,
#   'resource_subtype': 'enum',
#   'resource_type': 'custom_field',
#   'type': 'enum'},
#  {'gid': '1203889479039598',
#   'enabled': True,
#   'name': 'Pre-Condition',
#   'description': '',
#   'created_by': {'gid': '1203139226376547',
#    'name': 'Luke Hou',
#    'resource_type': 'user'},
#   'display_value': None,
#   'resource_subtype': 'text',
#   'resource_type': 'custom_field',
#   'text_value': None,
#   'type': 'text'},
#  {'gid': '1203880492084985',
#   'enabled': True,
#   'name': 'Test Step',
#   'description': '',
#   'created_by': {'gid': '1203139226376547',
#    'name': 'Luke Hou',
#    'resource_type': 'user'},
#   'display_value': '* 使用 CPOE 同時開立心臟內科檢查項目"心電圖 Pacemaker"及"E.K.G"',
#   'resource_subtype': 'text',
#   'resource_type': 'custom_field',
#   'text_value': '* 使用 CPOE 同時開立心臟內科檢查項目"心電圖 Pacemaker"及"E.K.G"',
#   'type': 'text'},
#  {'gid': '1203880492084987',
#   'enabled': True,
#   'name': 'Expected Result',
#   'description': '',
#   'created_by': {'gid': '1203139226376547',
#    'name': 'Luke Hou',
#    'resource_type': 'user'},
#   'display_value': '* 不可跳出展項重複的提示',
#   'resource_subtype': 'text',
#   'resource_type': 'custom_field',
#   'text_value': '* 不可跳出展項重複的提示',
#   'type': 'text'},
#  {'gid': '1203927944090616',
#   'enabled': True,
#   'name': 'Post-Condition',
#   'description': '',
#   'created_by': {'gid': '1203139226376547',
#    'name': 'Luke Hou',
#    'resource_type': 'user'},
#   'display_value': None,
#   'resource_subtype': 'text',
#   'resource_type': 'custom_field',
#   'text_value': None,
#   'type': 'text'},
#  {'gid': '1204151393723065',
#   'enabled': True,
#   'enum_options': [{'gid': '1204191076977825',
#     'color': 'red',
#     'enabled': True,
#     'name': 'v.next Hotfix',
#     'resource_type': 'enum_option'},
#    {'gid': '1204191215556915',
#     'color': 'red',
#     'enabled': True,
#     'name': 'v.next Feature',
#     'resource_type': 'enum_option'},
#    {'gid': '1204370943928676',
#     'color': 'none',
#     'enabled': True,
#     'name': 'XRT0011W',
#     'resource_type': 'enum_option'},
#    {'gid': '1204370943928675',
#     'color': 'none',
#     'enabled': True,
#     'name': 'XRT0010H',
#     'resource_type': 'enum_option'},
#    {'gid': '1204256012972448',
#     'color': 'none',
#     'enabled': True,
#     'name': 'XRT0009W',
#     'resource_type': 'enum_option'},
#    {'gid': '1204213162513273',
#     'color': 'none',
#     'enabled': True,
#     'name': 'XRT0008H',
#     'resource_type': 'enum_option'},
#    {'gid': '1204151393723066',
#     'color': 'none',
#     'enabled': True,
#     'name': 'XRT0007W',
#     'resource_type': 'enum_option'},
#    {'gid': '1204151393723067',
#     'color': 'none',
#     'enabled': True,
#     'name': 'XRT0006H',
#     'resource_type': 'enum_option'},
#    {'gid': '1204190912755613',
#     'color': 'none',
#     'enabled': True,
#     'name': 'XRT0005H',
#     'resource_type': 'enum_option'},
#    {'gid': '1204190396223455',
#     'color': 'none',
#     'enabled': True,
#     'name': 'XRT0004W',
#     'resource_type': 'enum_option'}],
#   'multi_enum_values': [],
#   'name': 'xRelease',
#   'description': '',
#   'created_by': {'gid': '1146187112437384',
#    'name': 'Robert Lu',
#    'resource_type': 'user'},
#   'display_value': None,
#   'resource_subtype': 'multi_enum',
#   'resource_type': 'custom_field',
#   'type': 'multi_enum'},
#  {'gid': '1203926363806253',
#   'enabled': True,
#   'name': 'Manual Test Date',
#   'description': '',
#   'created_by': {'gid': '1203139226376547',
#    'name': 'Luke Hou',
#    'resource_type': 'user'},
#   'display_value': None,
#   'resource_subtype': 'date',
#   'resource_type': 'custom_field',
#   'date_value': None,
#   'type': 'date'},
#  {'gid': '1203926363806260',
#   'enabled': True,
#   'enum_options': [{'gid': '1203926363806261',
#     'color': 'yellow-green',
#     'enabled': True,
#     'name': 'INTT',
#     'resource_type': 'enum_option'},
#    {'gid': '1203926363806262',
#     'color': 'purple',
#     'enabled': True,
#     'name': 'STAGE',
#     'resource_type': 'enum_option'},
#    {'gid': '1203926363806263',
#     'color': 'blue',
#     'enabled': True,
#     'name': 'PROD',
#     'resource_type': 'enum_option'},
#    {'gid': '1204305354230536',
#     'color': 'red',
#     'enabled': True,
#     'name': 'DEV',
#     'resource_type': 'enum_option'}],
#   'enum_value': None,
#   'name': 'Manual Test Environment',
#   'description': '',
#   'created_by': {'gid': '1203139226376547',
#    'name': 'Luke Hou',
#    'resource_type': 'user'},
#   'display_value': None,
#   'resource_subtype': 'enum',
#   'resource_type': 'custom_field',
#   'type': 'enum'},
#  {'gid': '1203926363806255',
#   'enabled': True,
#   'enum_options': [{'gid': '1204278011832321',
#     'color': 'yellow',
#     'enabled': True,
#     'name': 'Testing',
#     'resource_type': 'enum_option'},
#    {'gid': '1203926363806256',
#     'color': 'green',
#     'enabled': True,
#     'name': 'Passed',
#     'resource_type': 'enum_option'},
#    {'gid': '1203926363806257',
#     'color': 'red',
#     'enabled': True,
#     'name': 'Failed',
#     'resource_type': 'enum_option'},
#    {'gid': '1203926363806258',
#     'color': 'hot-pink',
#     'enabled': True,
#     'name': 'Triage',
#     'resource_type': 'enum_option'},
#    {'gid': '1204447833841095',
#     'color': 'orange',
#     'enabled': True,
#     'name': 'Pass with Note',
#     'resource_type': 'enum_option'}],
#   'enum_value': None,
#   'name': 'Manual Test Result',
#   'description': '',
#   'created_by': {'gid': '1203139226376547',
#    'name': 'Luke Hou',
#    'resource_type': 'user'},
#   'display_value': None,
#   'resource_subtype': 'enum',
#   'resource_type': 'custom_field',
#   'type': 'enum'},
#  {'gid': '1203954415389068',
#   'enabled': True,
#   'name': 'Manual Test Comment',
#   'description': '',
#   'created_by': {'gid': '1203139226376547',
#    'name': 'Luke Hou',
#    'resource_type': 'user'},
#   'display_value': None,
#   'resource_subtype': 'text',
#   'resource_type': 'custom_field',
#   'text_value': None,
#   'type': 'text'},
#  {'gid': '1203880512051789',
#   'enabled': True,
#   'enum_options': [{'gid': '1203880512051790',
#     'color': 'green',
#     'enabled': True,
#     'name': '醫師',
#     'resource_type': 'enum_option'},
#    {'gid': '1203880512051791',
#     'color': 'red',
#     'enabled': True,
#     'name': '跟診',
#     'resource_type': 'enum_option'},
#    {'gid': '1203880512051798',
#     'color': 'purple',
#     'enabled': True,
#     'name': '二線科人員',
#     'resource_type': 'enum_option'},
#    {'gid': '1203880512051792',
#     'color': 'orange',
#     'enabled': True,
#     'name': '藥師',
#     'resource_type': 'enum_option'},
#    {'gid': '1203880512051793',
#     'color': 'yellow-orange',
#     'enabled': True,
#     'name': '營養師',
#     'resource_type': 'enum_option'},
#    {'gid': '1203954415389020',
#     'color': 'yellow',
#     'enabled': True,
#     'name': 'ALL',
#     'resource_type': 'enum_option'}],
#   'multi_enum_values': [],
#   'name': 'Role',
#   'description': '',
#   'created_by': {'gid': '1203139226376547',
#    'name': 'Luke Hou',
#    'resource_type': 'user'},
#   'display_value': None,
#   'resource_subtype': 'multi_enum',
#   'resource_type': 'custom_field',
#   'type': 'multi_enum'},
#  {'gid': '1203964893025995',
#   'enabled': True,
#   'enum_options': [{'gid': '1203964893025996',
#     'color': 'green',
#     'enabled': True,
#     'name': 'PRD',
#     'resource_type': 'enum_option'},
#    {'gid': '1203964893025997',
#     'color': 'red',
#     'enabled': True,
#     'name': 'Defect',
#     'resource_type': 'enum_option'},
#    {'gid': '1203964893025998',
#     'color': 'orange',
#     'enabled': True,
#     'name': 'Testing',
#     'resource_type': 'enum_option'},
#    {'gid': '1203964893025999',
#     'color': 'yellow-orange',
#     'enabled': True,
#     'name': 'ETC',
#     'resource_type': 'enum_option'},
#    {'gid': '1204203317450647',
#     'color': 'yellow',
#     'enabled': True,
#     'name': 'CR',
#     'resource_type': 'enum_option'},
#    {'gid': '1204222443390006',
#     'color': 'yellow-green',
#     'enabled': True,
#     'name': 'E2E',
#     'resource_type': 'enum_option'},
#    {'gid': '1204222443390007',
#     'color': 'blue-green',
#     'enabled': True,
#     'name': 'Use Case',
#     'resource_type': 'enum_option'}],
#   'enum_value': {'gid': '1203964893025997',
#    'color': 'red',
#    'enabled': True,
#    'name': 'Defect',
#    'resource_type': 'enum_option'},
#   'name': 'Case Source',
#   'description': '',
#   'created_by': {'gid': '1203139226376547',
#    'name': 'Luke Hou',
#    'resource_type': 'user'},
#   'display_value': 'Defect',
#   'resource_subtype': 'enum',
#   'resource_type': 'custom_field',
#   'type': 'enum'},
#  {'gid': '1203889479039580',
#   'enabled': True,
#   'name': 'PRD',
#   'description': '',
#   'created_by': {'gid': '1203139226376547',
#    'name': 'Luke Hou',
#    'resource_type': 'user'},
#   'display_value': 'https://aics-his.atlassian.net/wiki/spaces/XHIS/pages/13041935/CPOE',
#   'resource_subtype': 'text',
#   'resource_type': 'custom_field',
#   'text_value': 'https://aics-his.atlassian.net/wiki/spaces/XHIS/pages/13041935/CPOE',
#   'type': 'text'},
#  {'gid': '1203965600326165',
#   'enabled': True,
#   'name': 'MainTicket',
#   'description': '',
#   'created_by': {'gid': '1203139226376547',
#    'name': 'Luke Hou',
#    'resource_type': 'user'},
#   'display_value': 'https://app.asana.com/0/1201610634708103/1204208394137246/f',
#   'resource_subtype': 'text',
#   'resource_type': 'custom_field',
#   'text_value': 'https://app.asana.com/0/1201610634708103/1204208394137246/f',
#   'type': 'text'},
#  {'gid': '1203934098502868',
#   'enabled': True,
#   'enum_options': [{'gid': '1203934098502869',
#     'color': 'green',
#     'enabled': True,
#     'name': 'CC Module',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098502990',
#     'color': 'orange',
#     'enabled': True,
#     'name': 'CC Web',
#     'resource_type': 'enum_option'},
#    {'gid': '1203946901342662',
#     'color': 'yellow',
#     'enabled': True,
#     'name': 'AICS SaaS',
#     'resource_type': 'enum_option'},
#    {'gid': '1203934098502870',
#     'color': 'red',
#     'enabled': True,
#     'name': 'Third Party',
#     'resource_type': 'enum_option'}],
#   'multi_enum_values': [],
#   'name': 'Non-xHIS',
#   'description': '',
#   'created_by': {'gid': '1203139226376547',
#    'name': 'Luke Hou',
#    'resource_type': 'user'},
#   'display_value': None,
#   'resource_subtype': 'multi_enum',
#   'resource_type': 'custom_field',
#   'type': 'multi_enum'},
#  {'gid': '1204483792823835',
#   'enabled': True,
#   'name': 'Automation Assignee',
#   'description': '',
#   'created_by': {'gid': '1203139226376547',
#    'name': 'Luke Hou',
#    'resource_type': 'user'},
#   'display_value': '',
#   'resource_subtype': 'people',
#   'resource_type': 'custom_field',
#   'people_value': [],
#   'type': 'people'},
#  {'gid': '1204036362646080',
#   'enabled': True,
#   'enum_options': [{'gid': '1204036362646081',
#     'color': 'green',
#     'enabled': True,
#     'name': 'Automated',
#     'resource_type': 'enum_option'},
#    {'gid': '1204124699309640',
#     'color': 'orange',
#     'enabled': True,
#     'name': 'Partially Automated',
#     'resource_type': 'enum_option'},
#    {'gid': '1204115697181473',
#     'color': 'yellow',
#     'enabled': True,
#     'name': 'In Progress',
#     'resource_type': 'enum_option'},
#    {'gid': '1204115697181474',
#     'color': 'red',
#     'enabled': True,
#     'name': 'To Automate',
#     'resource_type': 'enum_option'},
#    {'gid': '1204234906053321',
#     'color': 'hot-pink',
#     'enabled': True,
#     'name': 'Manual',
#     'resource_type': 'enum_option'},
#    {'gid': '1204234733879588',
#     'color': 'blue',
#     'enabled': True,
#     'name': 'TBD',
#     'resource_type': 'enum_option'}],
#   'enum_value': None,
#   'name': 'Automation Status',
#   'description': '',
#   'created_by': {'gid': '1203139226376547',
#    'name': 'Luke Hou',
#    'resource_type': 'user'},
#   'display_value': None,
#   'resource_subtype': 'enum',
#   'resource_type': 'custom_field',
#   'type': 'enum'},
#  {'gid': '1204115697181482',
#   'enabled': True,
#   'name': 'Automation ID',
#   'description': 'Automation Reference (e.g. caseID or caseName)',
#   'created_by': {'gid': '1203966328135185',
#    'name': 'Jiao Zhang',
#    'resource_type': 'user'},
#   'display_value': None,
#   'resource_subtype': 'text',
#   'resource_type': 'custom_field',
#   'text_value': None,
#   'type': 'text'},
#  {'gid': '1204115697181484',
#   'enabled': True,
#   'name': 'Automation Comments',
#   'description': 'E.g. Automation Solutions, Assessments by Automation Team',
#   'created_by': {'gid': '1203966328135185',
#    'name': 'Jiao Zhang',
#    'resource_type': 'user'},
#   'display_value': None,
#   'resource_subtype': 'text',
#   'resource_type': 'custom_field',
#   'text_value': None,
#   'type': 'text'},
#  {'gid': '1204352561007623',
#   'enabled': True,
#   'enum_options': [{'gid': '1204352561007624',
#     'color': 'green',
#     'enabled': True,
#     'name': 'Human',
#     'resource_type': 'enum_option'},
#    {'gid': '1204352561007625',
#     'color': 'red',
#     'enabled': True,
#     'name': 'gpt-3.5-turbo',
#     'resource_type': 'enum_option'}],
#   'enum_value': {'gid': '1204352561007624',
#    'color': 'green',
#    'enabled': True,
#    'name': 'Human',
#    'resource_type': 'enum_option'},
#   'name': 'Generated By',
#   'description': '',
#   'created_by': {'gid': '1203139226376547',
#    'name': 'Luke Hou',
#    'resource_type': 'user'},
#   'display_value': 'Human',
#   'resource_subtype': 'enum',
#   'resource_type': 'custom_field',
#   'type': 'enum'},
#  {'gid': '1204352561007629',
#   'enabled': True,
#   'name': 'Prompt Token',
#   'description': '',
#   'number_value': None,
#   'precision': 0,
#   'created_by': {'gid': '1203139226376547',
#    'name': 'Luke Hou',
#    'resource_type': 'user'},
#   'display_value': None,
#   'resource_subtype': 'number',
#   'resource_type': 'custom_field',
#   'type': 'number'},
#  {'gid': '1204352561007631',
#   'enabled': True,
#   'name': 'Completion Token',
#   'description': '',
#   'number_value': None,
#   'precision': 0,
#   'created_by': {'gid': '1203139226376547',
#    'name': 'Luke Hou',
#    'resource_type': 'user'},
#   'display_value': None,
#   'resource_subtype': 'number',
#   'resource_type': 'custom_field',
#   'type': 'number'},
#  {'gid': '1204352561007638',
#   'enabled': True,
#   'name': 'Total Token',
#   'description': '',
#   'number_value': None,
#   'precision': 0,
#   'created_by': {'gid': '1203139226376547',
#    'name': 'Luke Hou',
#    'resource_type': 'user'},
#   'display_value': None,
#   'resource_subtype': 'number',
#   'resource_type': 'custom_field',
#   'type': 'number'},
#  {'gid': '1204352561007633',
#   'enabled': True,
#   'name': 'Incur Time Cost',
#   'description': '',
#   'created_by': {'gid': '1203139226376547',
#    'name': 'Luke Hou',
#    'resource_type': 'user'},
#   'display_value': None,
#   'resource_subtype': 'text',
#   'resource_type': 'custom_field',
#   'text_value': None,
#   'type': 'text'}]

# %%
field_gid = {}
for field in result['custom_fields']:
    if field['name'] in needFields :
        field_gid[field['name']]= field['gid']
print(field_gid)
# Out:
# {'CaseSuite': '1203934098502833', 'Manual Test Coverage': '1203934098501463', 'Manual Test Priority': '1204395740629735', 'Pre-Condition': '1203889479039598', 'Test Step': '1203880492084985', 'Expected Result': '1203880492084987', 'xRelease': '1204151393723065', 'Manual Test Environment': '1203926363806260', 'Case Source': '1203964893025995', 'MainTicket': '1203965600326165', 'Generated By': '1204352561007623'}

# %%
fieldDict = {}
for field in result['data'][1:]:
    if field['custom_field']['name'] in needFields:
        print(field['custom_field']['name'])
        print(field)
        fieldDict[field['custom_field']['name']] = []
        for option in field['custom_field']['enum_options']:
            fieldDict[field['custom_field']['name']].append(option['name'])
# Out:
# xRelease
# {'gid': '1204151393723069', 'custom_field': {'gid': '1204151393723065', 'enum_options': [{'gid': '1204191076977825', 'color': 'red', 'enabled': True, 'name': 'v.next Hotfix', 'resource_type': 'enum_option'}, {'gid': '1204191215556915', 'color': 'red', 'enabled': True, 'name': 'v.next Feature', 'resource_type': 'enum_option'}, {'gid': '1204370943928676', 'color': 'none', 'enabled': True, 'name': 'XRT0011W', 'resource_type': 'enum_option'}, {'gid': '1204370943928675', 'color': 'none', 'enabled': True, 'name': 'XRT0010H', 'resource_type': 'enum_option'}, {'gid': '1204256012972448', 'color': 'none', 'enabled': True, 'name': 'XRT0009W', 'resource_type': 'enum_option'}, {'gid': '1204213162513273', 'color': 'none', 'enabled': True, 'name': 'XRT0008H', 'resource_type': 'enum_option'}, {'gid': '1204151393723066', 'color': 'none', 'enabled': True, 'name': 'XRT0007W', 'resource_type': 'enum_option'}, {'gid': '1204151393723067', 'color': 'none', 'enabled': True, 'name': 'XRT0006H', 'resource_type': 'enum_option'}, {'gid': '1204190912755613', 'color': 'none', 'enabled': True, 'name': 'XRT0005H', 'resource_type': 'enum_option'}, {'gid': '1204190396223455', 'color': 'none', 'enabled': True, 'name': 'XRT0004W', 'resource_type': 'enum_option'}], 'name': 'xRelease', 'resource_subtype': 'multi_enum', 'resource_type': 'custom_field', 'type': 'multi_enum'}, 'is_important': True, 'parent': {'gid': '1201610634708103', 'name': 'CC OPD - 2022-2023', 'resource_type': 'project'}, 'project': {'gid': '1201610634708103', 'name': 'CC OPD - 2022-2023', 'resource_type': 'project'}, 'resource_type': 'custom_field_setting'}

# %%
needFields= ['CaseSuite',
'Manual Test Coverage',
'Manual Test Priority',
'Manual Test Environment',
'Case Source',
'Generated By']

# %%
fieldDict = {}
for field in result['data'][1:]:
    if field['custom_field']['name'] in needFields:
        print(field['custom_field']['name'])
        fieldDict[field['custom_field']['name']] = []
        for option in field['custom_field']['enum_options']:
            fieldDict[field['custom_field']['name']].append(option['name'])
# Out:
# CaseSuite
# Manual Test Coverage
# Manual Test Priority
# Manual Test Environment
# Case Source
# Generated By

# %%
fieldDict
# Out:
# {'CaseSuite': ['即檢及列印',
#   '身分設定',
#   'SOAP',
#   '下診斷ICD',
#   '藥囑',
#   '醫囑',
#   '歷史病歷',
#   '稽核Rule',
#   '報告查詢',
#   '套餐(醫療)',
#   '就診明細',
#   '完成看診',
#   '身體數據',
#   '健保雲端',
#   '暫存及存回舊系統',
#   '清空看診資料(病歷維護)',
#   '健保卡及醫事卡',
#   '病患清單',
#   'Login',
#   'CPOE',
#   '院內公告',
#   '過敏及不良反應',
#   '列印',
#   '問卷',
#   '轉診',
#   'LifeCycle',
#   '環境設備',
#   '手術',
#   '電子表單',
#   '系統交互',
#   '電子病歷',
#   '疫苗',
#   '偕同編輯',
#   '掛號',
#   'DataSyc',
#   '再次完成看診',
#   '癌症相關',
#   '災難復原測試',
#   '架構及技術',
#   '個案管理',
#   '批價帳務',
#   '保險申報',
#   '其他',
#   'UI'],
#  'Manual Test Coverage': ['Smoke',
#   'Quick',
#   'Partial',
#   'Full',
#   'Backlog',
#   'DefectVerify',
#   'FectureVerify',
#   'E2E',
#   'Use Case',
#   'Offline'],
#  'Manual Test Priority': ['High', 'Medium', 'Low'],
#  'Manual Test Environment': ['INTT', 'STAGE', 'PROD', 'DEV'],
#  'Case Source': ['PRD',
#   'Defect',
#   'Testing',
#   'ETC',
#   'CR',
#   'E2E',
#   'Use Case',
#   'Acceptance Criteria'],
#  'Generated By': ['Human', 'gpt-3.5-turbo']}

# %%
fieldColorDict = {}
for field in result['data'][1:]:
    if field['custom_field']['name'] in needFields:
        print(field['custom_field']['name'])
        fieldColorDict[field['custom_field']['name']] = []
        for option in field['custom_field']['enum_options']:
            fieldColorDict[field['custom_field']['name']].append({option['name']:option['color']})
# Out:
# CaseSuite
# Manual Test Coverage
# Manual Test Priority
# Manual Test Environment
# Case Source
# Generated By

# %%
with open("./src/assets/optionsData.json", "w", encoding='utf8') as outfile:
    json.dump(fieldDict, outfile, ensure_ascii=False)

# %%
for field in result['data'][1:]:
    print(field['custom_field']['name'])
# Out:
# CaseSuite
# Manual Test Coverage
# Manual Test Priority
# Pre-Condition
# Test Step
# Expected Result
# Post-Condition
# Additional Step
# xRelease
# Manual Test Date
# Manual Test Environment
# Manual Test Result
# Manual Test Comment
# Role
# Case Source
# Test Step Status
# PRD
# MainTicket
# Non-xHIS
# Automation Status
# Automation ID
# Automation Comments
# Generated By
# Prompt Token
# Completion Token
# Total Token
# Incur Time Cost

# %%
result
# Out:
# {'data': [{'gid': '1203880492084954',
#    'custom_field': {'gid': '1203880492084953',
#     'name': 'Effort(Min.)',
#     'precision': 0,
#     'resource_subtype': 'number',
#     'resource_type': 'custom_field',
#     'type': 'number'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1203934098502836',
#    'custom_field': {'gid': '1203934098502833',
#     'enum_options': [{'gid': '1204387003439606',
#       'color': 'hot-pink',
#       'enabled': True,
#       'name': '即檢及列印',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502916',
#       'color': 'blue-green',
#       'enabled': True,
#       'name': '身分設定',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502998',
#       'color': 'yellow',
#       'enabled': True,
#       'name': 'SOAP',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098503008',
#       'color': 'green',
#       'enabled': True,
#       'name': '下診斷ICD',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098503062',
#       'color': 'pink',
#       'enabled': True,
#       'name': '藥囑',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502921',
#       'color': 'orange',
#       'enabled': True,
#       'name': '醫囑',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502962',
#       'color': 'cool-gray',
#       'enabled': True,
#       'name': '歷史病歷',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098503027',
#       'color': 'hot-pink',
#       'enabled': True,
#       'name': '稽核Rule',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502976',
#       'color': 'none',
#       'enabled': True,
#       'name': '報告查詢',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502991',
#       'color': 'none',
#       'enabled': True,
#       'name': '套餐(醫療)',
#       'resource_type': 'enum_option'},
#      {'gid': '1204466983046954',
#       'color': 'none',
#       'enabled': True,
#       'name': '就診明細',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502834',
#       'color': 'green',
#       'enabled': True,
#       'name': '完成看診',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502941',
#       'color': 'purple',
#       'enabled': True,
#       'name': '身體數據',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502936',
#       'color': 'indigo',
#       'enabled': True,
#       'name': '健保雲端',
#       'resource_type': 'enum_option'},
#      {'gid': '1204278087004936',
#       'color': 'aqua',
#       'enabled': True,
#       'name': '暫存及存回舊系統',
#       'resource_type': 'enum_option'},
#      {'gid': '1204278011832310',
#       'color': 'yellow-orange',
#       'enabled': True,
#       'name': '清空看診資料(病歷維護)',
#       'resource_type': 'enum_option'},
#      {'gid': '1204124924017144',
#       'color': 'none',
#       'enabled': True,
#       'name': '健保卡及醫事卡',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502908',
#       'color': 'yellow-green',
#       'enabled': True,
#       'name': '病患清單',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502854',
#       'color': 'orange',
#       'enabled': True,
#       'name': 'Login',
#       'resource_type': 'enum_option'},
#      {'gid': '1204150600824431',
#       'color': 'orange',
#       'enabled': True,
#       'name': 'CPOE',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502865',
#       'color': 'yellow',
#       'enabled': True,
#       'name': '院內公告',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502956',
#       'color': 'pink',
#       'enabled': True,
#       'name': '過敏及不良反應',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502933',
#       'color': 'blue',
#       'enabled': True,
#       'name': '列印',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502945',
#       'color': 'magenta',
#       'enabled': True,
#       'name': '問卷',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502953',
#       'color': 'hot-pink',
#       'enabled': True,
#       'name': '轉診',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502860',
#       'color': 'yellow-orange',
#       'enabled': True,
#       'name': 'LifeCycle',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502835',
#       'color': 'red',
#       'enabled': True,
#       'name': '環境設備',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502965',
#       'color': 'none',
#       'enabled': True,
#       'name': '手術',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502988',
#       'color': 'none',
#       'enabled': True,
#       'name': '電子表單',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098503005',
#       'color': 'none',
#       'enabled': True,
#       'name': '系統交互',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098503248',
#       'color': 'none',
#       'enabled': True,
#       'name': '電子病歷',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098503013',
#       'color': 'none',
#       'enabled': True,
#       'name': '疫苗',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098503070',
#       'color': 'none',
#       'enabled': True,
#       'name': '偕同編輯',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098503072',
#       'color': 'none',
#       'enabled': True,
#       'name': '掛號',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098503076',
#       'color': 'none',
#       'enabled': True,
#       'name': 'DataSyc',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098503081',
#       'color': 'none',
#       'enabled': True,
#       'name': '再次完成看診',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098503238',
#       'color': 'none',
#       'enabled': True,
#       'name': '癌症相關',
#       'resource_type': 'enum_option'},
#      {'gid': '1203943007360272',
#       'color': 'none',
#       'enabled': True,
#       'name': '災難復原測試',
#       'resource_type': 'enum_option'},
#      {'gid': '1203964893026037',
#       'color': 'none',
#       'enabled': True,
#       'name': '架構及技術',
#       'resource_type': 'enum_option'},
#      {'gid': '1204161832030784',
#       'color': 'none',
#       'enabled': True,
#       'name': '個案管理',
#       'resource_type': 'enum_option'},
#      {'gid': '1204172009992256',
#       'color': 'none',
#       'enabled': True,
#       'name': '批價帳務',
#       'resource_type': 'enum_option'},
#      {'gid': '1204172009992257',
#       'color': 'none',
#       'enabled': True,
#       'name': '保險申報',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098503078',
#       'color': 'none',
#       'enabled': True,
#       'name': '其他',
#       'resource_type': 'enum_option'},
#      {'gid': '1204437681145655',
#       'color': 'none',
#       'enabled': True,
#       'name': 'UI',
#       'resource_type': 'enum_option'}],
#     'name': 'CaseSuite',
#     'resource_subtype': 'multi_enum',
#     'resource_type': 'custom_field',
#     'type': 'multi_enum'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1203934098501468',
#    'custom_field': {'gid': '1203934098501463',
#     'enum_options': [{'gid': '1203934098501464',
#       'color': 'red',
#       'enabled': True,
#       'name': 'Smoke',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098501465',
#       'color': 'green',
#       'enabled': True,
#       'name': 'Quick',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098501466',
#       'color': 'indigo',
#       'enabled': True,
#       'name': 'Partial',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098501467',
#       'color': 'yellow-orange',
#       'enabled': True,
#       'name': 'Full',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098501469',
#       'color': 'cool-gray',
#       'enabled': False,
#       'name': 'Backlog',
#       'resource_type': 'enum_option'},
#      {'gid': '1204124924017134',
#       'color': 'yellow',
#       'enabled': False,
#       'name': 'DefectVerify',
#       'resource_type': 'enum_option'},
#      {'gid': '1204161832030785',
#       'color': 'yellow-green',
#       'enabled': False,
#       'name': 'FectureVerify',
#       'resource_type': 'enum_option'},
#      {'gid': '1204222443390009',
#       'color': 'blue-green',
#       'enabled': False,
#       'name': 'E2E',
#       'resource_type': 'enum_option'},
#      {'gid': '1204222443390010',
#       'color': 'aqua',
#       'enabled': False,
#       'name': 'Use Case',
#       'resource_type': 'enum_option'},
#      {'gid': '1203943007360270',
#       'color': 'orange',
#       'enabled': True,
#       'name': 'Offline',
#       'resource_type': 'enum_option'}],
#     'name': 'Manual Test Coverage',
#     'resource_subtype': 'multi_enum',
#     'resource_type': 'custom_field',
#     'type': 'multi_enum'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1204395740629740',
#    'custom_field': {'gid': '1204395740629735',
#     'enum_options': [{'gid': '1204395740629736',
#       'color': 'red',
#       'enabled': True,
#       'name': 'High',
#       'resource_type': 'enum_option'},
#      {'gid': '1204395740629737',
#       'color': 'orange',
#       'enabled': True,
#       'name': 'Medium',
#       'resource_type': 'enum_option'},
#      {'gid': '1204395740629738',
#       'color': 'yellow-orange',
#       'enabled': True,
#       'name': 'Low',
#       'resource_type': 'enum_option'}],
#     'name': 'Manual Test Priority',
#     'resource_subtype': 'enum',
#     'resource_type': 'custom_field',
#     'type': 'enum'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1203889479039599',
#    'custom_field': {'gid': '1203889479039598',
#     'name': 'Pre-Condition',
#     'resource_subtype': 'text',
#     'resource_type': 'custom_field',
#     'type': 'text'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1203880492084986',
#    'custom_field': {'gid': '1203880492084985',
#     'name': 'Test Step',
#     'resource_subtype': 'text',
#     'resource_type': 'custom_field',
#     'type': 'text'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1203880492084988',
#    'custom_field': {'gid': '1203880492084987',
#     'name': 'Expected Result',
#     'resource_subtype': 'text',
#     'resource_type': 'custom_field',
#     'type': 'text'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1203927944090617',
#    'custom_field': {'gid': '1203927944090616',
#     'name': 'Post-Condition',
#     'resource_subtype': 'text',
#     'resource_type': 'custom_field',
#     'type': 'text'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1203926363806065',
#    'custom_field': {'gid': '1203926363806064',
#     'name': 'Additional Step',
#     'resource_subtype': 'text',
#     'resource_type': 'custom_field',
#     'type': 'text'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1204446526756500',
#    'custom_field': {'gid': '1204151393723065',
#     'enum_options': [{'gid': '1204191076977825',
#       'color': 'red',
#       'enabled': True,
#       'name': 'v.next Hotfix',
#       'resource_type': 'enum_option'},
#      {'gid': '1204191215556915',
#       'color': 'red',
#       'enabled': True,
#       'name': 'v.next Feature',
#       'resource_type': 'enum_option'},
#      {'gid': '1204370943928676',
#       'color': 'none',
#       'enabled': True,
#       'name': 'XRT0011W',
#       'resource_type': 'enum_option'},
#      {'gid': '1204370943928675',
#       'color': 'none',
#       'enabled': True,
#       'name': 'XRT0010H',
#       'resource_type': 'enum_option'},
#      {'gid': '1204256012972448',
#       'color': 'none',
#       'enabled': True,
#       'name': 'XRT0009W',
#       'resource_type': 'enum_option'},
#      {'gid': '1204213162513273',
#       'color': 'none',
#       'enabled': True,
#       'name': 'XRT0008H',
#       'resource_type': 'enum_option'},
#      {'gid': '1204151393723066',
#       'color': 'none',
#       'enabled': True,
#       'name': 'XRT0007W',
#       'resource_type': 'enum_option'},
#      {'gid': '1204151393723067',
#       'color': 'none',
#       'enabled': True,
#       'name': 'XRT0006H',
#       'resource_type': 'enum_option'},
#      {'gid': '1204190912755613',
#       'color': 'none',
#       'enabled': True,
#       'name': 'XRT0005H',
#       'resource_type': 'enum_option'},
#      {'gid': '1204190396223455',
#       'color': 'none',
#       'enabled': True,
#       'name': 'XRT0004W',
#       'resource_type': 'enum_option'}],
#     'name': 'xRelease',
#     'resource_subtype': 'multi_enum',
#     'resource_type': 'custom_field',
#     'type': 'multi_enum'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1203926363806254',
#    'custom_field': {'gid': '1203926363806253',
#     'name': 'Manual Test Date',
#     'resource_subtype': 'date',
#     'resource_type': 'custom_field',
#     'type': 'date'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1203926363806264',
#    'custom_field': {'gid': '1203926363806260',
#     'enum_options': [{'gid': '1203926363806261',
#       'color': 'yellow-green',
#       'enabled': True,
#       'name': 'INTT',
#       'resource_type': 'enum_option'},
#      {'gid': '1203926363806262',
#       'color': 'purple',
#       'enabled': True,
#       'name': 'STAGE',
#       'resource_type': 'enum_option'},
#      {'gid': '1203926363806263',
#       'color': 'blue',
#       'enabled': True,
#       'name': 'PROD',
#       'resource_type': 'enum_option'},
#      {'gid': '1204305354230536',
#       'color': 'red',
#       'enabled': True,
#       'name': 'DEV',
#       'resource_type': 'enum_option'}],
#     'name': 'Manual Test Environment',
#     'resource_subtype': 'enum',
#     'resource_type': 'custom_field',
#     'type': 'enum'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1203926363806259',
#    'custom_field': {'gid': '1203926363806255',
#     'enum_options': [{'gid': '1204278011832321',
#       'color': 'yellow',
#       'enabled': True,
#       'name': 'Testing',
#       'resource_type': 'enum_option'},
#      {'gid': '1203926363806256',
#       'color': 'green',
#       'enabled': True,
#       'name': 'Passed',
#       'resource_type': 'enum_option'},
#      {'gid': '1203926363806257',
#       'color': 'red',
#       'enabled': True,
#       'name': 'Failed',
#       'resource_type': 'enum_option'},
#      {'gid': '1203926363806258',
#       'color': 'hot-pink',
#       'enabled': True,
#       'name': 'Triage',
#       'resource_type': 'enum_option'},
#      {'gid': '1204447833841095',
#       'color': 'orange',
#       'enabled': True,
#       'name': 'Pass with Note',
#       'resource_type': 'enum_option'}],
#     'name': 'Manual Test Result',
#     'resource_subtype': 'enum',
#     'resource_type': 'custom_field',
#     'type': 'enum'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1203954415389069',
#    'custom_field': {'gid': '1203954415389068',
#     'name': 'Manual Test Comment',
#     'resource_subtype': 'text',
#     'resource_type': 'custom_field',
#     'type': 'text'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1203880512051794',
#    'custom_field': {'gid': '1203880512051789',
#     'enum_options': [{'gid': '1203880512051790',
#       'color': 'green',
#       'enabled': True,
#       'name': '醫師',
#       'resource_type': 'enum_option'},
#      {'gid': '1203880512051791',
#       'color': 'red',
#       'enabled': True,
#       'name': '跟診',
#       'resource_type': 'enum_option'},
#      {'gid': '1203880512051798',
#       'color': 'purple',
#       'enabled': True,
#       'name': '二線科人員',
#       'resource_type': 'enum_option'},
#      {'gid': '1203880512051792',
#       'color': 'orange',
#       'enabled': True,
#       'name': '藥師',
#       'resource_type': 'enum_option'},
#      {'gid': '1203880512051793',
#       'color': 'yellow-orange',
#       'enabled': True,
#       'name': '營養師',
#       'resource_type': 'enum_option'},
#      {'gid': '1203954415389020',
#       'color': 'yellow',
#       'enabled': True,
#       'name': 'ALL',
#       'resource_type': 'enum_option'}],
#     'name': 'Role',
#     'resource_subtype': 'multi_enum',
#     'resource_type': 'custom_field',
#     'type': 'multi_enum'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1203964893026000',
#    'custom_field': {'gid': '1203964893025995',
#     'enum_options': [{'gid': '1203964893025996',
#       'color': 'green',
#       'enabled': True,
#       'name': 'PRD',
#       'resource_type': 'enum_option'},
#      {'gid': '1203964893025997',
#       'color': 'red',
#       'enabled': True,
#       'name': 'Defect',
#       'resource_type': 'enum_option'},
#      {'gid': '1203964893025998',
#       'color': 'orange',
#       'enabled': True,
#       'name': 'Testing',
#       'resource_type': 'enum_option'},
#      {'gid': '1203964893025999',
#       'color': 'yellow-orange',
#       'enabled': True,
#       'name': 'ETC',
#       'resource_type': 'enum_option'},
#      {'gid': '1204203317450647',
#       'color': 'yellow',
#       'enabled': True,
#       'name': 'CR',
#       'resource_type': 'enum_option'},
#      {'gid': '1204222443390006',
#       'color': 'yellow-green',
#       'enabled': True,
#       'name': 'E2E',
#       'resource_type': 'enum_option'},
#      {'gid': '1204222443390007',
#       'color': 'blue-green',
#       'enabled': True,
#       'name': 'Use Case',
#       'resource_type': 'enum_option'},
#      {'gid': '1204222443390008',
#       'color': 'aqua',
#       'enabled': False,
#       'name': 'Acceptance Criteria',
#       'resource_type': 'enum_option'}],
#     'name': 'Case Source',
#     'resource_subtype': 'enum',
#     'resource_type': 'custom_field',
#     'type': 'enum'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1204171875281594',
#    'custom_field': {'gid': '1204171875281591',
#     'enum_options': [{'gid': '1204181033870573',
#       'color': 'yellow',
#       'enabled': False,
#       'name': 'SE Todo',
#       'resource_type': 'enum_option'},
#      {'gid': '1204171875281592',
#       'color': 'red',
#       'enabled': True,
#       'name': 'SE Changed',
#       'resource_type': 'enum_option'},
#      {'gid': '1204313371813783',
#       'color': 'yellow-orange',
#       'enabled': False,
#       'name': 'Legacy Case',
#       'resource_type': 'enum_option'},
#      {'gid': '1204171875281593',
#       'color': 'blue-green',
#       'enabled': False,
#       'name': 'Automation ???',
#       'resource_type': 'enum_option'},
#      {'gid': '1204231431532925',
#       'color': 'orange',
#       'enabled': True,
#       'name': 'PM Changed',
#       'resource_type': 'enum_option'}],
#     'name': 'Test Step Status',
#     'resource_subtype': 'enum',
#     'resource_type': 'custom_field',
#     'type': 'enum'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1203889479039581',
#    'custom_field': {'gid': '1203889479039580',
#     'name': 'PRD',
#     'resource_subtype': 'text',
#     'resource_type': 'custom_field',
#     'type': 'text'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1203965600326166',
#    'custom_field': {'gid': '1203965600326165',
#     'name': 'MainTicket',
#     'resource_subtype': 'text',
#     'resource_type': 'custom_field',
#     'type': 'text'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1203934098502871',
#    'custom_field': {'gid': '1203934098502868',
#     'enum_options': [{'gid': '1203934098502869',
#       'color': 'green',
#       'enabled': True,
#       'name': 'CC Module',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502990',
#       'color': 'orange',
#       'enabled': True,
#       'name': 'CC Web',
#       'resource_type': 'enum_option'},
#      {'gid': '1203946901342662',
#       'color': 'yellow',
#       'enabled': True,
#       'name': 'AICS SaaS',
#       'resource_type': 'enum_option'},
#      {'gid': '1203934098502870',
#       'color': 'red',
#       'enabled': True,
#       'name': 'Third Party',
#       'resource_type': 'enum_option'},
#      {'gid': '1203943007360274',
#       'color': 'yellow-orange',
#       'enabled': False,
#       'name': 'Azure SaaS',
#       'resource_type': 'enum_option'}],
#     'name': 'Non-xHIS',
#     'resource_subtype': 'multi_enum',
#     'resource_type': 'custom_field',
#     'type': 'multi_enum'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1204036364493280',
#    'custom_field': {'gid': '1204036362646080',
#     'enum_options': [{'gid': '1204036362646081',
#       'color': 'green',
#       'enabled': True,
#       'name': 'Automated',
#       'resource_type': 'enum_option'},
#      {'gid': '1204036362646082',
#       'color': 'yellow',
#       'enabled': False,
#       'name': '進行中',
#       'resource_type': 'enum_option'},
#      {'gid': '1204124699309640',
#       'color': 'orange',
#       'enabled': True,
#       'name': 'Partially Automated',
#       'resource_type': 'enum_option'},
#      {'gid': '1204115697181473',
#       'color': 'yellow',
#       'enabled': True,
#       'name': 'In Progress',
#       'resource_type': 'enum_option'},
#      {'gid': '1204036364493279',
#       'color': 'orange',
#       'enabled': False,
#       'name': '待討論',
#       'resource_type': 'enum_option'},
#      {'gid': '1204115697181474',
#       'color': 'red',
#       'enabled': True,
#       'name': 'To Automate',
#       'resource_type': 'enum_option'},
#      {'gid': '1204234906053321',
#       'color': 'hot-pink',
#       'enabled': True,
#       'name': 'Manual',
#       'resource_type': 'enum_option'},
#      {'gid': '1204234733879588',
#       'color': 'blue',
#       'enabled': True,
#       'name': 'TBD',
#       'resource_type': 'enum_option'}],
#     'name': 'Automation Status',
#     'resource_subtype': 'enum',
#     'resource_type': 'custom_field',
#     'type': 'enum'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1204115697181483',
#    'custom_field': {'gid': '1204115697181482',
#     'name': 'Automation ID',
#     'resource_subtype': 'text',
#     'resource_type': 'custom_field',
#     'type': 'text'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1204115697181485',
#    'custom_field': {'gid': '1204115697181484',
#     'name': 'Automation Comments',
#     'resource_subtype': 'text',
#     'resource_type': 'custom_field',
#     'type': 'text'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1204352561007626',
#    'custom_field': {'gid': '1204352561007623',
#     'enum_options': [{'gid': '1204352561007624',
#       'color': 'green',
#       'enabled': True,
#       'name': 'Human',
#       'resource_type': 'enum_option'},
#      {'gid': '1204352561007625',
#       'color': 'red',
#       'enabled': True,
#       'name': 'gpt-3.5-turbo',
#       'resource_type': 'enum_option'}],
#     'name': 'Generated By',
#     'resource_subtype': 'enum',
#     'resource_type': 'custom_field',
#     'type': 'enum'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1204352561007630',
#    'custom_field': {'gid': '1204352561007629',
#     'name': 'Prompt Token',
#     'precision': 0,
#     'resource_subtype': 'number',
#     'resource_type': 'custom_field',
#     'type': 'number'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1204352561007632',
#    'custom_field': {'gid': '1204352561007631',
#     'name': 'Completion Token',
#     'precision': 0,
#     'resource_subtype': 'number',
#     'resource_type': 'custom_field',
#     'type': 'number'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1204352561007639',
#    'custom_field': {'gid': '1204352561007638',
#     'name': 'Total Token',
#     'precision': 0,
#     'resource_subtype': 'number',
#     'resource_type': 'custom_field',
#     'type': 'number'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'},
#   {'gid': '1204352561007634',
#    'custom_field': {'gid': '1204352561007633',
#     'name': 'Incur Time Cost',
#     'resource_subtype': 'text',
#     'resource_type': 'custom_field',
#     'type': 'text'},
#    'is_important': True,
#    'parent': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'project': {'gid': '1203880491753826',
#     'name': 'MasterScript',
#     'resource_type': 'project'},
#    'resource_type': 'custom_field_setting'}]}

# %%
result['data'][15]
# Out:
# {'gid': '1203964893026000',
#  'custom_field': {'gid': '1203964893025995',
#   'enum_options': [{'gid': '1203964893025996',
#     'color': 'green',
#     'enabled': True,
#     'name': 'PRD',
#     'resource_type': 'enum_option'},
#    {'gid': '1203964893025997',
#     'color': 'red',
#     'enabled': True,
#     'name': 'Defect',
#     'resource_type': 'enum_option'},
#    {'gid': '1203964893025998',
#     'color': 'orange',
#     'enabled': True,
#     'name': 'Testing',
#     'resource_type': 'enum_option'},
#    {'gid': '1203964893025999',
#     'color': 'yellow-orange',
#     'enabled': True,
#     'name': 'ETC',
#     'resource_type': 'enum_option'},
#    {'gid': '1204203317450647',
#     'color': 'yellow',
#     'enabled': True,
#     'name': 'CR',
#     'resource_type': 'enum_option'},
#    {'gid': '1204222443390006',
#     'color': 'yellow-green',
#     'enabled': True,
#     'name': 'E2E',
#     'resource_type': 'enum_option'},
#    {'gid': '1204222443390007',
#     'color': 'blue-green',
#     'enabled': True,
#     'name': 'Use Case',
#     'resource_type': 'enum_option'},
#    {'gid': '1204222443390008',
#     'color': 'aqua',
#     'enabled': False,
#     'name': 'Acceptance Criteria',
#     'resource_type': 'enum_option'}],
#   'name': 'Case Source',
#   'resource_subtype': 'enum',
#   'resource_type': 'custom_field',
#   'type': 'enum'},
#  'is_important': True,
#  'parent': {'gid': '1203880491753826',
#   'name': 'MasterScript',
#   'resource_type': 'project'},
#  'project': {'gid': '1203880491753826',
#   'name': 'MasterScript',
#   'resource_type': 'project'},
#  'resource_type': 'custom_field_setting'}

# %%
fieldColorDict
# Out:
# {'CaseSuite': [{'即檢及列印': 'hot-pink'},
#   {'身分設定': 'blue-green'},
#   {'SOAP': 'yellow'},
#   {'下診斷ICD': 'green'},
#   {'藥囑': 'pink'},
#   {'醫囑': 'orange'},
#   {'歷史病歷': 'cool-gray'},
#   {'稽核Rule': 'hot-pink'},
#   {'報告查詢': 'none'},
#   {'套餐(醫療)': 'none'},
#   {'就診明細': 'none'},
#   {'完成看診': 'green'},
#   {'身體數據': 'purple'},
#   {'健保雲端': 'indigo'},
#   {'暫存及存回舊系統': 'aqua'},
#   {'清空看診資料(病歷維護)': 'yellow-orange'},
#   {'健保卡及醫事卡': 'none'},
#   {'病患清單': 'yellow-green'},
#   {'Login': 'orange'},
#   {'CPOE': 'orange'},
#   {'院內公告': 'yellow'},
#   {'過敏及不良反應': 'pink'},
#   {'列印': 'blue'},
#   {'問卷': 'magenta'},
#   {'轉診': 'hot-pink'},
#   {'LifeCycle': 'yellow-orange'},
#   {'環境設備': 'red'},
#   {'手術': 'none'},
#   {'電子表單': 'none'},
#   {'系統交互': 'none'},
#   {'電子病歷': 'none'},
#   {'疫苗': 'none'},
#   {'偕同編輯': 'none'},
#   {'掛號': 'none'},
#   {'DataSyc': 'none'},
#   {'再次完成看診': 'none'},
#   {'癌症相關': 'none'},
#   {'災難復原測試': 'none'},
#   {'架構及技術': 'none'},
#   {'個案管理': 'none'},
#   {'批價帳務': 'none'},
#   {'保險申報': 'none'},
#   {'其他': 'none'},
#   {'UI': 'none'}],
#  'Manual Test Coverage': [{'Smoke': 'red'},
#   {'Quick': 'green'},
#   {'Partial': 'indigo'},
#   {'Full': 'yellow-orange'},
#   {'Backlog': 'cool-gray'},
#   {'DefectVerify': 'yellow'},
#   {'FectureVerify': 'yellow-green'},
#   {'E2E': 'blue-green'},
#   {'Use Case': 'aqua'},
#   {'Offline': 'orange'}],
#  'Manual Test Priority': [{'High': 'red'},
#   {'Medium': 'orange'},
#   {'Low': 'yellow-orange'}],
#  'Manual Test Environment': [{'INTT': 'yellow-green'},
#   {'STAGE': 'purple'},
#   {'PROD': 'blue'},
#   {'DEV': 'red'}],
#  'Case Source': [{'PRD': 'green'},
#   {'Defect': 'red'},
#   {'Testing': 'orange'},
#   {'ETC': 'yellow-orange'},
#   {'CR': 'yellow'},
#   {'E2E': 'yellow-green'},
#   {'Use Case': 'blue-green'},
#   {'Acceptance Criteria': 'aqua'}],
#  'Generated By': [{'Human': 'green'}, {'gpt-3.5-turbo': 'red'}]}

# %%
result['data'][3]['custom_field']
# Out:
# {'gid': '1204395740629735',
#  'enum_options': [{'gid': '1204395740629736',
#    'color': 'red',
#    'enabled': True,
#    'name': 'High',
#    'resource_type': 'enum_option'},
#   {'gid': '1204395740629737',
#    'color': 'orange',
#    'enabled': True,
#    'name': 'Medium',
#    'resource_type': 'enum_option'},
#   {'gid': '1204395740629738',
#    'color': 'yellow-orange',
#    'enabled': True,
#    'name': 'Low',
#    'resource_type': 'enum_option'}],
#  'name': 'Manual Test Priority',
#  'resource_subtype': 'enum',
#  'resource_type': 'custom_field',
#  'type': 'enum'}
